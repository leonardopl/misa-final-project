# %% [markdown]
# Experiment with SegResNetDS

# %%
import os
import time
import datetime

import matplotlib.pyplot as plt
import numpy as np

import datasets as D
import torch
from torch.utils.tensorboard import SummaryWriter

from monai.inferers import sliding_window_inference

from monai.networks.nets import SegResNetDS

from monai.config import print_config
from monai import transforms, data, losses, optimizers, metrics
from monai.utils import set_determinism
print_config()
# Out:
# MONAI version: 1.3.0
# Numpy version: 1.26.0
# Pytorch version: 2.1.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 865972f7a791bf7b42efbcd87c8402bd865b329e
# MONAI __file__: c:\Users\<username>\miniforge3\envs\p310-torch\lib\site-packages\monai\__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.1.0
# scikit-image version: 0.22.0
# scipy version: 1.11.3
# Pillow version: 10.0.1
# Tensorboard version: 2.15.1
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.16.1
# tqdm version: 4.66.1
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.5
# pandas version: 2.1.3
# einops version: 0.7.0
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# ## Setup data path and parameters

# %%
PROJECT_DATASET_DIR = "D:\\Files\\Projects\\MAIA\\UdG\\MISA\\Project"

DATA_DIR = PROJECT_DATASET_DIR + "\\dataset"

EXP_NAME = "exp01-SegResNet" # name of the experiment

BATCH_SIZE_TRAIN = 8
BATCH_SIZE_INFER = 4

LR = 2e-4
PATIENCE = 20

NUM_CLASSES = 4

# %%
EXP_ID = EXP_NAME+"-"+time.strftime("%Y%m%d_%H_%M_%S", time.localtime(time.time()))

root_dir = PROJECT_DATASET_DIR + "\\experiments\\" + EXP_ID
print(root_dir)
# Out:
# D:\Files\Projects\MAIA\UdG\MISA\Project\experiments\exp01-SegResNet-20231230_18_50_32

# %%
# make directory
if not os.path.exists(root_dir):
    os.makedirs(root_dir)

# %%
tb_writer = SummaryWriter(root_dir)

# %% [markdown]
# ## Set seed

# %%
set_determinism(seed=42)

# %% [markdown]
# ## Setup transforms

# %%
# dataset info
IMG_SIZE = (256, 128, 256)
BG_LABEL = 0
CSF_LABEL = 1
GM_LABEL = 2
WM_LABEL = 3

ROI = (128, 128, 128)
NUM_PATCHES_PER_IMAGE = 4
NUM_PATCHES_PER_ITER = 2

# %%
train_transforms = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image", "label"], ensure_channel_first=True),
        transforms.ToTensord(keys=["image", "label"]),
        transforms.EnsureTyped(keys=["image", "label"], track_meta=True),
        transforms.NormalizeIntensityd(keys="image", nonzero=True),
        transforms.Spacingd(keys=["image", "label"], pixdim=(1.0, 1.0, 1.0), mode=("bilinear", "nearest")),
       
        transforms.CropForegroundd(
            allow_smaller=True,
            keys=["image", "label"],
            source_key="image",
            k_divisible=[ROI[0], ROI[1], ROI[2]],
        ),
        transforms.RandCropByLabelClassesd(
            keys=["image", "label"],
            label_key="label",
            spatial_size=[ROI[0], ROI[1], ROI[2]],
            num_classes=NUM_CLASSES,
            num_samples=NUM_PATCHES_PER_IMAGE,
        ),
        transforms.RandFlipd(keys=["image", "label"], prob=0.2, spatial_axis=0),
        transforms.RandFlipd(keys=["image", "label"], prob=0.2, spatial_axis=1),
        transforms.RandFlipd(keys=["image", "label"], prob=0.2, spatial_axis=2),
        transforms.RandRotate90d(keys=["image", "label"], prob=0.2, max_k=3),
        transforms.RandScaleIntensityd(keys="image", factors=0.1, prob=0.1),
        transforms.RandShiftIntensityd(keys="image", offsets=0.1, prob=0.1),
    ]
)
val_transforms = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image", "label"], ensure_channel_first=True),
        transforms.ToTensord(keys=["image", "label"]),
        transforms.EnsureTyped(keys=["image", "label"], track_meta=True),
        transforms.NormalizeIntensityd(keys="image", nonzero=True),
    ]
)
test_transforms = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image"], ensure_channel_first=True),
        transforms.ToTensord(keys=["image"]),
        transforms.EnsureTyped(keys=["image"], track_meta=True),
        transforms.NormalizeIntensityd(keys="image", nonzero=True),
    ]
)

# %% [markdown]
# ## Load the dataset

# %%
json_file_path = os.path.join(DATA_DIR, "misa_datalist.json")
if not os.path.exists(json_file_path):
    D.generate_misa_json_datalist(DATA_DIR, "misa_datalist.json")
train_datalist = D.load_misa_datalist(json_file_path, "training")
val_datalist = D.load_misa_datalist(json_file_path, "validation")
test_datalist = D.load_misa_datalist(json_file_path, "testing")

train_ds = data.Dataset(
    data=train_datalist,
    transform=train_transforms,
)
val_ds = data.Dataset(
    data=val_datalist,
    transform=val_transforms,
)
test_ds = data.Dataset(
    data=test_datalist,
    transform=test_transforms,
)

train_loader = data.DataLoader(
    train_ds,
    batch_size=BATCH_SIZE_TRAIN,
    shuffle=True,
    num_workers=8,
)
val_loader = data.DataLoader(
    val_ds,
    batch_size=BATCH_SIZE_INFER,
    shuffle=False,
    num_workers=8,
)
test_loader = data.DataLoader(
    test_ds,
    batch_size=BATCH_SIZE_INFER,
    shuffle=False,
    num_workers=8,
)

# %% [markdown]
# ## Check the data

# %%
train_data_example = train_ds[0][0]
print(f"image shape: {train_data_example['image'].shape}")
print(f"image type: {train_data_example['image'].dtype}")
print(f"label shape: {train_data_example['label'].shape}")
print(f"label type: {train_data_example['label'].dtype}")
plt.figure("image", (6, 4))
plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(train_data_example["image"].cpu().numpy()[0, :, :, ROI[2]//2], cmap="gray")
plt.subplot(1, 2, 2)
plt.title("label")
plt.imshow(train_data_example["label"].cpu().numpy()[0, :, :, ROI[2]//2])
plt.show()
# Out:
# image shape: torch.Size([1, 128, 128, 128])
# image type: torch.float32
# label shape: torch.Size([1, 128, 128, 128])
# label type: torch.float32

# %%
val_data_example = val_ds[0]
print(f"image shape: {val_data_example['image'].shape}")
print(f"image type: {val_data_example['image'].dtype}")
print(f"label shape: {val_data_example['label'].shape}")
print(f"label type: {val_data_example['label'].dtype}")
plt.figure("image", (6, 4))
plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(val_data_example["image"].cpu().numpy()[0, :, :, IMG_SIZE[2]//2], cmap="gray")
plt.subplot(1, 2, 2)
plt.title("label")
plt.imshow(val_data_example["label"].cpu().numpy()[0, :, :, IMG_SIZE[2]//2])
plt.show()
# Out:
# image shape: torch.Size([1, 256, 128, 256])
# image type: torch.float32
# label shape: torch.Size([1, 256, 128, 256])
# label type: torch.float32

# %%
test_data_example = test_ds[0]
print(f"image shape: {test_data_example['image'].shape}")
print(f"image type: {test_data_example['image'].dtype}")
plt.figure("image", (6, 4))
plt.subplot(1, 1, 1)
plt.title("image")
plt.imshow(test_data_example["image"].cpu().numpy()[0, :, :, IMG_SIZE[2]//2], cmap="gray")
plt.show()
# Out:
# image shape: torch.Size([1, 256, 128, 256])
# image type: torch.float32

# %% [markdown]
# ## Create Model, Loss, Optimizer

# %%
max_epochs = 1000
val_interval = 1
VAL_AMP = True

# standard PyTorch program style: create model, loss function and optimizer
device = torch.device("cuda:0")

model = SegResNetDS(
    blocks_down=[1, 2, 2, 4, 4],
    dsdepth=1,
    in_channels=1,
    init_filters=32,
    out_channels=NUM_CLASSES,
).to(device)
    
# model = SwinUNETR(
#     img_size=ROI,
#     in_channels=1,
#     out_channels=4,
#     feature_size=48,
#     use_checkpoint=True,
#     use_v2=True,
# ).to(device)


loss_function = losses.DiceCELoss(to_onehot_y=True, softmax=True, squared_pred=True, include_background=True, smooth_nr=0, smooth_dr=1e-5)
optimizer = torch.optim.AdamW(model.parameters(), LR, weight_decay=1e-5)
lr_scheduler = optimizers.WarmupCosineSchedule(
    optimizer,
    t_total=max_epochs//val_interval+1,
    warmup_multiplier=0.1,
    warmup_steps=max_epochs//100
)

# define inference method
def inference(input):
    def _compute(input):
        roi_size = ROI
        sw_batch_size = NUM_PATCHES_PER_ITER
        return sliding_window_inference(input, roi_size, sw_batch_size, model, overlap=0.5)

    if VAL_AMP:
        with torch.cuda.amp.autocast():
            return _compute(input)
    else:
        return _compute(input)

# use amp to accelerate training
scaler = torch.cuda.amp.GradScaler()
# enable cuDNN benchmark
torch.backends.cudnn.benchmark = True

# %%
import torchinfo

torchinfo.summary(model, input_size=(BATCH_SIZE_TRAIN, 1, ROI[0], ROI[1], ROI[2]))
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# SegResNetDS                                        [8, 4, 128, 128, 128]     --
# ├─SegResEncoder: 1-1                               [8, 32, 128, 128, 128]    --
# │    └─Conv3d: 2-1                                 [8, 32, 128, 128, 128]    864
# │    └─ModuleList: 2-2                             --                        --
# │    │    └─ModuleDict: 3-1                        --                        110,720
# │    │    └─ModuleDict: 3-2                        --                        664,064
# │    │    └─ModuleDict: 3-3                        --                        2,655,232
# │    │    └─ModuleDict: 3-4                        --                        17,698,816
# │    │    └─ModuleDict: 3-5                        --                        56,631,296
# ├─ModuleList: 1-2                                  --                        --
# │    └─ModuleDict: 2-3                             --                        --
# │    │    └─UpSample: 3-6                          [8, 256, 16, 16, 16]      3,538,944
# │    │    └─Sequential: 3-7                        [8, 256, 16, 16, 16]      3,539,968
# │    └─ModuleDict: 2-4                             --                        --
# │    │    └─UpSample: 3-8                          [8, 128, 32, 32, 32]      884,736
# │    │    └─Sequential: 3-9                        [8, 128, 32, 32, 32]      885,248
# │    └─ModuleDict: 2-5                             --                        --
# │    │    └─UpSample: 3-10                         [8, 64, 64, 64, 64]       221,184
# │    │    └─Sequential: 3-11                       [8, 64, 64, 64, 64]       221,440
# │    └─ModuleDict: 2-6                             --                        --
# │    │    └─UpSample: 3-12                         [8, 32, 128, 128, 128]    55,296
# │    │    └─Sequential: 3-13                       [8, 32, 128, 128, 128]    55,424
# │    │    └─Conv3d: 3-14                           [8, 4, 128, 128, 128]     132
# ====================================================================================================
# Total params: 87,163,364
# Trainable params: 87,163,364
# Non-trainable params: 0
# Total mult-adds (T): 6.73
# ====================================================================================================
# Input size (MB): 67.11
# Forward/backward pass size (MB): 64038.63
# Params size (MB): 348.65
# Estimated Total Size (MB): 64454.40
# ====================================================================================================

# %% [markdown]
# ## Setup Metrics and Early Stopper

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0, mode='min'):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_metric = float('inf') if mode == 'min' else float('-inf')
        self.mode = mode

    def early_stop(self, validation_metric):
        if self.mode == 'min':
            improved = (validation_metric + self.min_delta) < self.best_metric
        else:
            improved = (validation_metric - self.min_delta) > self.best_metric

        if improved:
            self.best_metric = validation_metric
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False
    
early_stopper = EarlyStopper(patience=PATIENCE, min_delta=1e-4, mode='max')

dice_metric = metrics.DiceMetric(include_background=True, reduction="mean_batch", get_not_nans=False)

# %% [markdown]
# ## Execute a typical PyTorch training process

# %%
post_label = transforms.AsDiscrete(to_onehot=4)
post_pred = transforms.AsDiscrete(argmax=True, to_onehot=4)

best_avg_dice = -1

best_dice_epoch = -1

epoch_loss_values = []
lr_values = []

dice_avg_values = []
dice_wm_values = []
dice_gm_values = []
dice_csf_values = []

stop_training = False

total_start = time.time()
for epoch in range(max_epochs):
    epoch_start = time.time()
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for train_data in train_loader:
        step_start = time.time()
        step += 1
        
        inputs_l = (
            train_data["image"].as_tensor()
            if isinstance(train_data["image"], data.MetaTensor)
            else train_data["image"]
        )
        labels_l = (
            train_data["label"].as_tensor()
            if isinstance(train_data["label"], data.MetaTensor)
            else train_data["label"]
        )

        _idx = torch.randperm(inputs_l.shape[0])
        inputs_l = inputs_l[_idx]
        labels_l = labels_l[_idx]

        loss_loop = []
        for _k in range(inputs_l.shape[0] // NUM_PATCHES_PER_ITER):
            inputs = inputs_l[_k * NUM_PATCHES_PER_ITER : (_k + 1) * NUM_PATCHES_PER_ITER, ...]
            labels = labels_l[_k * NUM_PATCHES_PER_ITER : (_k + 1) * NUM_PATCHES_PER_ITER, ...]

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # print(f"inputs shape: {inputs.shape}")
            # print(f"intput type: {type(inputs)}")
                    
            optimizer.zero_grad()
            with torch.cuda.amp.autocast():
                outputs = model(inputs)
                # print(f"outputs type: {type(outputs)}")
                loss = loss_function(outputs, labels)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            loss_loop.append(loss.item())
        
        # print(f"loss_loop type[0]: {type(loss_loop[0])}")
        # print(f"loss_loop[0]: {type(loss_loop[0])}")
        epoch_loss += np.mean(loss_loop)
        print(
            f"{epoch + 1}/{max_epochs}, "
            f"{step}/{len(train_ds) // train_loader.batch_size}"
            f", train_loss: {loss.item():.4f}"
            f", step time: {(time.time() - step_start):.4f}"
        )
        
    lr_values.append(lr_scheduler.get_last_lr()[0])
    lr_scheduler.step()
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1}, average loss: {epoch_loss:.4f}, lr: {lr_values[-1]:.6f}\n")
    tb_writer.add_scalar("epoch_train_loss", epoch_loss, epoch + 1)

    if (epoch + 1) % val_interval == 0:
        model.eval()
        val_start = time.time()
        with torch.no_grad():
            for idx, val_data in enumerate(val_loader):
                
                val_inputs = (
                    val_data["image"].as_tensor()
                    if isinstance(val_data["image"], data.MetaTensor)
                    else val_data["image"]
                )
                val_labels = (
                    val_data["label"].as_tensor()
                    if isinstance(val_data["label"], data.MetaTensor)
                    else val_data["label"]
                )
                
                val_inputs = val_inputs.to(device)
                val_labels = val_labels.to(device)

                val_outputs = inference(val_inputs)
                
                # print(f"val_outputs type: {type(val_outputs)}")
                # print(f"val_outputs shape: {val_outputs.shape}")
                # print(f"val_labels type: {type(val_labels)}")
                # print(f"val_labels shape: {val_labels.shape}")
                
                val_outputs_list = data.decollate_batch(val_outputs)
                val_labels_list = data.decollate_batch(val_labels)
                
                # print(f"val_outputs_list type: {type(val_outputs_list)}")
                # print(f"val_outputs_list len: {len(val_outputs_list)}")
                # print(f"val_outputs_list[0] type: {type(val_outputs_list[0])}")
                # print(f"val_outputs_list[0] shape: {val_outputs_list[0].shape}")
                
                # val_outputs_convert = [post_pred(post_sigmoid(val_output)) for val_output in val_outputs_list]
                val_outputs_convert = [post_pred(val_output) for val_output in val_outputs_list]
                val_labels_convert = [post_label(val_label) for val_label in val_labels_list]
                
                # print(f"val_outputs_convert type: {type(val_outputs_convert)}")
                # print(f"val_outputs_convert len: {len(val_outputs_convert)}")
                # print(f"val_outputs_convert[0] type: {type(val_outputs_convert[0])}")
                # print(f"val_outputs_convert[0] shape: {val_outputs_convert[0].shape}")
                
                dice_metric(val_outputs_convert, val_labels_convert)
                    
                print(
                    f"val {epoch + 1}/{max_epochs}, {idx + 1}/{len(val_loader)}",
                    f", time {(time.time() - val_start):.4f}s",
                )
                val_start = time.time()
                
            dice_all = dice_metric.aggregate()
            # print(dice_all)
            # print(f"dice_all type: {type(dice_all)}"
            #         f"\ndice_all shape: {dice_all.shape}")
            dice_bg = dice_all[BG_LABEL].item()
            dice_wm = dice_all[WM_LABEL].item()
            dice_gm = dice_all[GM_LABEL].item()
            dice_csf = dice_all[CSF_LABEL].item()
            dice_avg = torch.mean(dice_all[1:]).item()
            dice_metric.reset()
            
            dice_avg_values.append(dice_avg)
            dice_wm_values.append(dice_wm)
            dice_gm_values.append(dice_gm)
            dice_csf_values.append(dice_csf)
            
            tb_writer.add_scalar("epoch_val_dice_avg", dice_avg, epoch + 1)
            tb_writer.add_scalar("epoch_val_dice_bg", dice_bg, epoch + 1)
            tb_writer.add_scalar("epoch_val_dice_wm", dice_wm, epoch + 1)
            tb_writer.add_scalar("epoch_val_dice_gm", dice_gm, epoch + 1)
            tb_writer.add_scalar("epoch_val_dice_csf", dice_csf, epoch + 1)
            tb_writer.add_scalar("learning_rate", lr_values[-1], epoch + 1)
            

            if dice_avg > best_avg_dice:
                best_avg_dice = dice_avg
                best_dice_epoch = epoch + 1
                torch.save(
                    model.state_dict(),
                    os.path.join(root_dir, "best_metric_model.pth"),
                )
                print("\n=> SAVED NEW BEST MODEL!")

            print(
                f"\nCURRENT epoch: {epoch + 1}"
                f"\nCURRENT avg dice: {dice_avg:.4f}"
                f"\nCURRENT wm dice: {dice_wm:.4f}"
                f"\nCURRENT gm dice: {dice_gm:.4f}"
                f"\nCURRENT csf dice: {dice_csf:.4f}"
                
                f"\n"
                
                f"\nBEST avg dice: {best_avg_dice:.4f} at epoch: {best_dice_epoch}"
            )
            
            if early_stopper.early_stop(dice_avg):             
                print("\n=> EARLY STOPPING")
                stop_training = True
                break
            
    print(f"\ntime consuming of epoch {epoch + 1} is: {str(datetime.timedelta(seconds=int((time.time() - epoch_start))))}")
    
    if stop_training:
        break
    
total_time = time.time() - total_start
# Out:
# ----------
# epoch 1/1000
# 1/1000, 1/1, train_loss: 1.4634, step time: 12.0942
# 1/1000, 2/1, train_loss: 1.3956, step time: 1.9790
# epoch 1, average loss: 1.6060, lr: 0.000020
#
# val 1/1000, 1/2 , time 9.8633s
# val 1/1000, 2/2 , time 1.2575s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 1
# CURRENT avg dice: 0.3222
# CURRENT wm dice: 0.8239
# CURRENT gm dice: 0.1418
# CURRENT csf dice: 0.0009
#
# BEST avg dice: 0.3222 at epoch: 1
#
# time consuming of epoch 1 is: 0:00:52
# ----------
# epoch 2/1000
# 2/1000, 1/1, train_loss: 0.6780, step time: 8.0666
# 2/1000, 2/1, train_loss: 0.6533, step time: 1.9613
# epoch 2, average loss: 0.8577, lr: 0.000038
#
# val 2/1000, 1/2 , time 9.8788s
# val 2/1000, 2/2 , time 0.6810s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 2
# CURRENT avg dice: 0.5274
# CURRENT wm dice: 0.8203
# CURRENT gm dice: 0.7619
# CURRENT csf dice: 0.0000
#
# BEST avg dice: 0.5274 at epoch: 2
#
# time consuming of epoch 2 is: 0:00:47
# ----------
# epoch 3/1000
# 3/1000, 1/1, train_loss: 0.5898, step time: 7.9483
# 3/1000, 2/1, train_loss: 0.4974, step time: 1.9771
# epoch 3, average loss: 0.6027, lr: 0.000056
#
# val 3/1000, 1/2 , time 10.0968s
# val 3/1000, 2/2 , time 0.6902s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 3
# CURRENT avg dice: 0.6648
# CURRENT wm dice: 0.8423
# CURRENT gm dice: 0.7768
# CURRENT csf dice: 0.3751
#
# BEST avg dice: 0.6648 at epoch: 3
#
# time consuming of epoch 3 is: 0:00:48
# ----------
# epoch 4/1000
# 4/1000, 1/1, train_loss: 0.4931, step time: 7.9595
# 4/1000, 2/1, train_loss: 0.4333, step time: 1.9640
# epoch 4, average loss: 0.4761, lr: 0.000074
#
# val 4/1000, 1/2 , time 9.9369s
# val 4/1000, 2/2 , time 0.6845s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 4
# CURRENT avg dice: 0.6908
# CURRENT wm dice: 0.8428
# CURRENT gm dice: 0.8185
# CURRENT csf dice: 0.4111
#
# BEST avg dice: 0.6908 at epoch: 4
#
# time consuming of epoch 4 is: 0:00:48
# ----------
# epoch 5/1000
# 5/1000, 1/1, train_loss: 0.3473, step time: 8.0761
# 5/1000, 2/1, train_loss: 0.4201, step time: 1.9613
# epoch 5, average loss: 0.3830, lr: 0.000092
#
# val 5/1000, 1/2 , time 9.9322s
# val 5/1000, 2/2 , time 0.6799s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 5
# CURRENT avg dice: 0.7866
# CURRENT wm dice: 0.8705
# CURRENT gm dice: 0.8150
# CURRENT csf dice: 0.6745
#
# BEST avg dice: 0.7866 at epoch: 5
#
# time consuming of epoch 5 is: 0:00:47
# ----------
# epoch 6/1000
# 6/1000, 1/1, train_loss: 0.2690, step time: 8.0215
# 6/1000, 2/1, train_loss: 0.3479, step time: 1.9592
# epoch 6, average loss: 0.3424, lr: 0.000110
#
# val 6/1000, 1/2 , time 9.7470s
# val 6/1000, 2/2 , time 0.6776s
#
# CURRENT epoch: 6
# CURRENT avg dice: 0.7720
# CURRENT wm dice: 0.8767
# CURRENT gm dice: 0.8722
# CURRENT csf dice: 0.5670
#
# BEST avg dice: 0.7866 at epoch: 5
#
# time consuming of epoch 6 is: 0:00:46
# ----------
# epoch 7/1000
# 7/1000, 1/1, train_loss: 0.3000, step time: 7.9851
# 7/1000, 2/1, train_loss: 0.2569, step time: 1.9561
# epoch 7, average loss: 0.3079, lr: 0.000128
#
# val 7/1000, 1/2 , time 9.8892s
# val 7/1000, 2/2 , time 0.6789s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 7
# CURRENT avg dice: 0.8151
# CURRENT wm dice: 0.8613
# CURRENT gm dice: 0.8326
# CURRENT csf dice: 0.7512
#
# BEST avg dice: 0.8151 at epoch: 7
#
# time consuming of epoch 7 is: 0:00:46
# ----------
# epoch 8/1000
# 8/1000, 1/1, train_loss: 0.2965, step time: 7.9473
# 8/1000, 2/1, train_loss: 0.2763, step time: 1.9577
# epoch 8, average loss: 0.2902, lr: 0.000146
#
# val 8/1000, 1/2 , time 9.7743s
# val 8/1000, 2/2 , time 0.6797s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 8
# CURRENT avg dice: 0.8394
# CURRENT wm dice: 0.8826
# CURRENT gm dice: 0.8270
# CURRENT csf dice: 0.8087
#
# BEST avg dice: 0.8394 at epoch: 8
#
# time consuming of epoch 8 is: 0:00:46
# ----------
# epoch 9/1000
# 9/1000, 1/1, train_loss: 0.3030, step time: 7.9286
# 9/1000, 2/1, train_loss: 0.2601, step time: 1.9557
# epoch 9, average loss: 0.2961, lr: 0.000164
#
# val 9/1000, 1/2 , time 9.9158s
# val 9/1000, 2/2 , time 0.6821s
#
# CURRENT epoch: 9
# CURRENT avg dice: 0.7289
# CURRENT wm dice: 0.8726
# CURRENT gm dice: 0.8694
# CURRENT csf dice: 0.4448
#
# BEST avg dice: 0.8394 at epoch: 8
#
# time consuming of epoch 9 is: 0:00:46
# ----------
# epoch 10/1000
# 10/1000, 1/1, train_loss: 0.2432, step time: 8.0672
# 10/1000, 2/1, train_loss: 0.3008, step time: 1.9741
# epoch 10, average loss: 0.2823, lr: 0.000182
#
# val 10/1000, 1/2 , time 13.5122s
# val 10/1000, 2/2 , time 0.6944s
#
# CURRENT epoch: 10
# CURRENT avg dice: 0.8314
# CURRENT wm dice: 0.8838
# CURRENT gm dice: 0.8856
# CURRENT csf dice: 0.7247
#
# BEST avg dice: 0.8394 at epoch: 8
#
# time consuming of epoch 10 is: 0:00:52
# ----------
# epoch 11/1000
# 11/1000, 1/1, train_loss: 0.3379, step time: 8.8267
# 11/1000, 2/1, train_loss: 0.2484, step time: 1.9569
# epoch 11, average loss: 0.2711, lr: 0.000200
#
# val 11/1000, 1/2 , time 9.8591s
# val 11/1000, 2/2 , time 0.6769s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 11
# CURRENT avg dice: 0.8583
# CURRENT wm dice: 0.8744
# CURRENT gm dice: 0.8923
# CURRENT csf dice: 0.8081
#
# BEST avg dice: 0.8583 at epoch: 11
#
# time consuming of epoch 11 is: 0:00:51
# ----------
# epoch 12/1000
# 12/1000, 1/1, train_loss: 0.2712, step time: 8.8134
# 12/1000, 2/1, train_loss: 0.2709, step time: 1.9599
# epoch 12, average loss: 0.2505, lr: 0.000200
#
# val 12/1000, 1/2 , time 9.9947s
# val 12/1000, 2/2 , time 0.6822s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 12
# CURRENT avg dice: 0.8672
# CURRENT wm dice: 0.8908
# CURRENT gm dice: 0.8883
# CURRENT csf dice: 0.8226
#
# BEST avg dice: 0.8672 at epoch: 12
#
# time consuming of epoch 12 is: 0:00:46
# ----------
# epoch 13/1000
# 13/1000, 1/1, train_loss: 0.3039, step time: 8.8133
# 13/1000, 2/1, train_loss: 0.2267, step time: 1.9600
# epoch 13, average loss: 0.2473, lr: 0.000200
#
# val 13/1000, 1/2 , time 9.6794s
# val 13/1000, 2/2 , time 0.6763s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 13
# CURRENT avg dice: 0.8753
# CURRENT wm dice: 0.8908
# CURRENT gm dice: 0.8856
# CURRENT csf dice: 0.8496
#
# BEST avg dice: 0.8753 at epoch: 13
#
# time consuming of epoch 13 is: 0:00:46
# ----------
# epoch 14/1000
# 14/1000, 1/1, train_loss: 0.2062, step time: 8.8165
# 14/1000, 2/1, train_loss: 0.3150, step time: 1.9664
# epoch 14, average loss: 0.2553, lr: 0.000200
#
# val 14/1000, 1/2 , time 10.3585s
# val 14/1000, 2/2 , time 0.6829s
#
# CURRENT epoch: 14
# CURRENT avg dice: 0.8745
# CURRENT wm dice: 0.8925
# CURRENT gm dice: 0.8848
# CURRENT csf dice: 0.8462
#
# BEST avg dice: 0.8753 at epoch: 13
#
# time consuming of epoch 14 is: 0:00:47
# ----------
# epoch 15/1000
# 15/1000, 1/1, train_loss: 0.2020, step time: 7.9564
# 15/1000, 2/1, train_loss: 0.2184, step time: 1.9595
# epoch 15, average loss: 0.2367, lr: 0.000200
#
# val 15/1000, 1/2 , time 9.9434s
# val 15/1000, 2/2 , time 0.6814s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 15
# CURRENT avg dice: 0.8774
# CURRENT wm dice: 0.8958
# CURRENT gm dice: 0.8800
# CURRENT csf dice: 0.8564
#
# BEST avg dice: 0.8774 at epoch: 15
#
# time consuming of epoch 15 is: 0:00:47
# ----------
# epoch 16/1000
# 16/1000, 1/1, train_loss: 0.2060, step time: 7.9633
# 16/1000, 2/1, train_loss: 0.2147, step time: 1.9735
# epoch 16, average loss: 0.2402, lr: 0.000200
#
# val 16/1000, 1/2 , time 9.7510s
# val 16/1000, 2/2 , time 0.6812s
#
# CURRENT epoch: 16
# CURRENT avg dice: 0.8506
# CURRENT wm dice: 0.8908
# CURRENT gm dice: 0.9072
# CURRENT csf dice: 0.7537
#
# BEST avg dice: 0.8774 at epoch: 15
#
# time consuming of epoch 16 is: 0:00:46
# ----------
# epoch 17/1000
# 17/1000, 1/1, train_loss: 0.3243, step time: 8.0655
# 17/1000, 2/1, train_loss: 0.2447, step time: 1.9582
# epoch 17, average loss: 0.2628, lr: 0.000200
#
# val 17/1000, 1/2 , time 9.7535s
# val 17/1000, 2/2 , time 0.6775s
#
# CURRENT epoch: 17
# CURRENT avg dice: 0.8465
# CURRENT wm dice: 0.8589
# CURRENT gm dice: 0.8681
# CURRENT csf dice: 0.8126
#
# BEST avg dice: 0.8774 at epoch: 15
#
# time consuming of epoch 17 is: 0:00:46
# ----------
# epoch 18/1000
# 18/1000, 1/1, train_loss: 0.2261, step time: 8.0493
# 18/1000, 2/1, train_loss: 0.2351, step time: 1.9617
# epoch 18, average loss: 0.2756, lr: 0.000200
#
# val 18/1000, 1/2 , time 9.7180s
# val 18/1000, 2/2 , time 0.6798s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 18
# CURRENT avg dice: 0.8829
# CURRENT wm dice: 0.9018
# CURRENT gm dice: 0.9115
# CURRENT csf dice: 0.8354
#
# BEST avg dice: 0.8829 at epoch: 18
#
# time consuming of epoch 18 is: 0:00:47
# ----------
# epoch 19/1000
# 19/1000, 1/1, train_loss: 0.2168, step time: 8.1125
# 19/1000, 2/1, train_loss: 0.1706, step time: 1.9567
# epoch 19, average loss: 0.2063, lr: 0.000200
#
# val 19/1000, 1/2 , time 9.7219s
# val 19/1000, 2/2 , time 0.6789s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 19
# CURRENT avg dice: 0.8950
# CURRENT wm dice: 0.9073
# CURRENT gm dice: 0.9116
# CURRENT csf dice: 0.8660
#
# BEST avg dice: 0.8950 at epoch: 19
#
# time consuming of epoch 19 is: 0:00:46
# ----------
# epoch 20/1000
# 20/1000, 1/1, train_loss: 0.2409, step time: 7.9659
# 20/1000, 2/1, train_loss: 0.1705, step time: 1.9574
# epoch 20, average loss: 0.2047, lr: 0.000200
#
# val 20/1000, 1/2 , time 10.1370s
# val 20/1000, 2/2 , time 0.6847s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 20
# CURRENT avg dice: 0.8980
# CURRENT wm dice: 0.9101
# CURRENT gm dice: 0.9143
# CURRENT csf dice: 0.8695
#
# BEST avg dice: 0.8980 at epoch: 20
#
# time consuming of epoch 20 is: 0:00:47
# ----------
# epoch 21/1000
# 21/1000, 1/1, train_loss: 0.1464, step time: 8.8430
# 21/1000, 2/1, train_loss: 0.2507, step time: 1.9683
# epoch 21, average loss: 0.2036, lr: 0.000200
#
# val 21/1000, 1/2 , time 9.8535s
# val 21/1000, 2/2 , time 0.6802s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 21
# CURRENT avg dice: 0.9002
# CURRENT wm dice: 0.9121
# CURRENT gm dice: 0.9147
# CURRENT csf dice: 0.8737
#
# BEST avg dice: 0.9002 at epoch: 21
#
# time consuming of epoch 21 is: 0:00:47
# ----------
# epoch 22/1000
# 22/1000, 1/1, train_loss: 0.2115, step time: 8.1030
# 22/1000, 2/1, train_loss: 0.1718, step time: 1.9627
# epoch 22, average loss: 0.1910, lr: 0.000200
#
# val 22/1000, 1/2 , time 9.7724s
# val 22/1000, 2/2 , time 0.6776s
#
# CURRENT epoch: 22
# CURRENT avg dice: 0.8922
# CURRENT wm dice: 0.9082
# CURRENT gm dice: 0.9006
# CURRENT csf dice: 0.8679
#
# BEST avg dice: 0.9002 at epoch: 21
#
# time consuming of epoch 22 is: 0:00:46
# ----------
# epoch 23/1000
# 23/1000, 1/1, train_loss: 0.1983, step time: 8.1161
# 23/1000, 2/1, train_loss: 0.2173, step time: 1.9584
# epoch 23, average loss: 0.1967, lr: 0.000200
#
# val 23/1000, 1/2 , time 9.5856s
# val 23/1000, 2/2 , time 0.6794s
#
# CURRENT epoch: 23
# CURRENT avg dice: 0.8904
# CURRENT wm dice: 0.9113
# CURRENT gm dice: 0.9126
# CURRENT csf dice: 0.8473
#
# BEST avg dice: 0.9002 at epoch: 21
#
# time consuming of epoch 23 is: 0:00:45
# ----------
# epoch 24/1000
# 24/1000, 1/1, train_loss: 0.2384, step time: 7.9699
# 24/1000, 2/1, train_loss: 0.1947, step time: 1.9587
# epoch 24, average loss: 0.1941, lr: 0.000200
#
# val 24/1000, 1/2 , time 9.5970s
# val 24/1000, 2/2 , time 0.6794s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 24
# CURRENT avg dice: 0.9002
# CURRENT wm dice: 0.9099
# CURRENT gm dice: 0.9193
# CURRENT csf dice: 0.8714
#
# BEST avg dice: 0.9002 at epoch: 24
#
# time consuming of epoch 24 is: 0:00:45
# ----------
# epoch 25/1000
# 25/1000, 1/1, train_loss: 0.1931, step time: 8.0175
# 25/1000, 2/1, train_loss: 0.1795, step time: 1.9619
# epoch 25, average loss: 0.1999, lr: 0.000200
#
# val 25/1000, 1/2 , time 9.7459s
# val 25/1000, 2/2 , time 0.6767s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 25
# CURRENT avg dice: 0.9027
# CURRENT wm dice: 0.9121
# CURRENT gm dice: 0.9181
# CURRENT csf dice: 0.8779
#
# BEST avg dice: 0.9027 at epoch: 25
#
# time consuming of epoch 25 is: 0:00:46
# ----------
# epoch 26/1000
# 26/1000, 1/1, train_loss: 0.1952, step time: 7.9351
# 26/1000, 2/1, train_loss: 0.2231, step time: 1.9627
# epoch 26, average loss: 0.1992, lr: 0.000200
#
# val 26/1000, 1/2 , time 9.5784s
# val 26/1000, 2/2 , time 0.6808s
#
# CURRENT epoch: 26
# CURRENT avg dice: 0.8989
# CURRENT wm dice: 0.9107
# CURRENT gm dice: 0.9177
# CURRENT csf dice: 0.8684
#
# BEST avg dice: 0.9027 at epoch: 25
#
# time consuming of epoch 26 is: 0:00:45
# ----------
# epoch 27/1000
# 27/1000, 1/1, train_loss: 0.1471, step time: 7.9560
# 27/1000, 2/1, train_loss: 0.1385, step time: 1.9595
# epoch 27, average loss: 0.1853, lr: 0.000200
#
# val 27/1000, 1/2 , time 10.6697s
# val 27/1000, 2/2 , time 0.6972s
#
# CURRENT epoch: 27
# CURRENT avg dice: 0.8996
# CURRENT wm dice: 0.9147
# CURRENT gm dice: 0.9184
# CURRENT csf dice: 0.8657
#
# BEST avg dice: 0.9027 at epoch: 25
#
# time consuming of epoch 27 is: 0:00:46
# ----------
# epoch 28/1000
# 28/1000, 1/1, train_loss: 0.2032, step time: 8.1020
# 28/1000, 2/1, train_loss: 0.2526, step time: 1.9607
# epoch 28, average loss: 0.2185, lr: 0.000200
#
# val 28/1000, 1/2 , time 9.7563s
# val 28/1000, 2/2 , time 0.6812s
#
# CURRENT epoch: 28
# CURRENT avg dice: 0.7638
# CURRENT wm dice: 0.8648
# CURRENT gm dice: 0.8691
# CURRENT csf dice: 0.5574
#
# BEST avg dice: 0.9027 at epoch: 25
#
# time consuming of epoch 28 is: 0:00:46
# ----------
# epoch 29/1000
# 29/1000, 1/1, train_loss: 0.2969, step time: 7.9611
# 29/1000, 2/1, train_loss: 0.1944, step time: 1.9586
# epoch 29, average loss: 0.2186, lr: 0.000200
#
# val 29/1000, 1/2 , time 9.7337s
# val 29/1000, 2/2 , time 0.6818s
#
# CURRENT epoch: 29
# CURRENT avg dice: 0.8411
# CURRENT wm dice: 0.9011
# CURRENT gm dice: 0.8881
# CURRENT csf dice: 0.7339
#
# BEST avg dice: 0.9027 at epoch: 25
#
# time consuming of epoch 29 is: 0:00:46
# ----------
# epoch 30/1000
# 30/1000, 1/1, train_loss: 0.1327, step time: 7.9853
# 30/1000, 2/1, train_loss: 0.1838, step time: 1.9617
# epoch 30, average loss: 0.2038, lr: 0.000200
#
# val 30/1000, 1/2 , time 9.9230s
# val 30/1000, 2/2 , time 0.6805s
#
# CURRENT epoch: 30
# CURRENT avg dice: 0.8709
# CURRENT wm dice: 0.8998
# CURRENT gm dice: 0.8774
# CURRENT csf dice: 0.8355
#
# BEST avg dice: 0.9027 at epoch: 25
#
# time consuming of epoch 30 is: 0:00:46
# ----------
# epoch 31/1000
# 31/1000, 1/1, train_loss: 0.1794, step time: 8.1228
# 31/1000, 2/1, train_loss: 0.2603, step time: 1.9617
# epoch 31, average loss: 0.2174, lr: 0.000200
#
# val 31/1000, 1/2 , time 9.7120s
# val 31/1000, 2/2 , time 0.6786s
#
# CURRENT epoch: 31
# CURRENT avg dice: 0.8972
# CURRENT wm dice: 0.9093
# CURRENT gm dice: 0.9190
# CURRENT csf dice: 0.8632
#
# BEST avg dice: 0.9027 at epoch: 25
#
# time consuming of epoch 31 is: 0:00:46
# ----------
# epoch 32/1000
# 32/1000, 1/1, train_loss: 0.2433, step time: 8.0256
# 32/1000, 2/1, train_loss: 0.2077, step time: 1.9730
# epoch 32, average loss: 0.1922, lr: 0.000200
#
# val 32/1000, 1/2 , time 9.8816s
# val 32/1000, 2/2 , time 0.6806s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 32
# CURRENT avg dice: 0.9035
# CURRENT wm dice: 0.9172
# CURRENT gm dice: 0.9189
# CURRENT csf dice: 0.8743
#
# BEST avg dice: 0.9035 at epoch: 32
#
# time consuming of epoch 32 is: 0:00:46
# ----------
# epoch 33/1000
# 33/1000, 1/1, train_loss: 0.1912, step time: 8.0560
# 33/1000, 2/1, train_loss: 0.1809, step time: 1.9641
# epoch 33, average loss: 0.1931, lr: 0.000200
#
# val 33/1000, 1/2 , time 10.1290s
# val 33/1000, 2/2 , time 0.6791s
#
# CURRENT epoch: 33
# CURRENT avg dice: 0.8967
# CURRENT wm dice: 0.9156
# CURRENT gm dice: 0.9107
# CURRENT csf dice: 0.8639
#
# BEST avg dice: 0.9035 at epoch: 32
#
# time consuming of epoch 33 is: 0:00:47
# ----------
# epoch 34/1000
# 34/1000, 1/1, train_loss: 0.1525, step time: 8.6469
# 34/1000, 2/1, train_loss: 0.1443, step time: 1.9580
# epoch 34, average loss: 0.1693, lr: 0.000200
#
# val 34/1000, 1/2 , time 9.6608s
# val 34/1000, 2/2 , time 0.6769s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 34
# CURRENT avg dice: 0.9123
# CURRENT wm dice: 0.9257
# CURRENT gm dice: 0.9251
# CURRENT csf dice: 0.8861
#
# BEST avg dice: 0.9123 at epoch: 34
#
# time consuming of epoch 34 is: 0:00:47
# ----------
# epoch 35/1000
# 35/1000, 1/1, train_loss: 0.1944, step time: 7.9776
# 35/1000, 2/1, train_loss: 0.1820, step time: 1.9592
# epoch 35, average loss: 0.1746, lr: 0.000200
#
# val 35/1000, 1/2 , time 9.9465s
# val 35/1000, 2/2 , time 0.6793s
#
# CURRENT epoch: 35
# CURRENT avg dice: 0.9057
# CURRENT wm dice: 0.9202
# CURRENT gm dice: 0.9145
# CURRENT csf dice: 0.8824
#
# BEST avg dice: 0.9123 at epoch: 34
#
# time consuming of epoch 35 is: 0:00:46
# ----------
# epoch 36/1000
# 36/1000, 1/1, train_loss: 0.1813, step time: 8.0525
# 36/1000, 2/1, train_loss: 0.1672, step time: 1.9609
# epoch 36, average loss: 0.1728, lr: 0.000200
#
# val 36/1000, 1/2 , time 9.9105s
# val 36/1000, 2/2 , time 0.6790s
#
# CURRENT epoch: 36
# CURRENT avg dice: 0.9112
# CURRENT wm dice: 0.9227
# CURRENT gm dice: 0.9316
# CURRENT csf dice: 0.8793
#
# BEST avg dice: 0.9123 at epoch: 34
#
# time consuming of epoch 36 is: 0:00:46
# ----------
# epoch 37/1000
# 37/1000, 1/1, train_loss: 0.1871, step time: 8.0637
# 37/1000, 2/1, train_loss: 0.2272, step time: 1.9609
# epoch 37, average loss: 0.1880, lr: 0.000200
#
# val 37/1000, 1/2 , time 9.9270s
# val 37/1000, 2/2 , time 0.6800s
#
# CURRENT epoch: 37
# CURRENT avg dice: 0.9001
# CURRENT wm dice: 0.9035
# CURRENT gm dice: 0.9245
# CURRENT csf dice: 0.8722
#
# BEST avg dice: 0.9123 at epoch: 34
#
# time consuming of epoch 37 is: 0:00:46
# ----------
# epoch 38/1000
# 38/1000, 1/1, train_loss: 0.1597, step time: 7.9581
# 38/1000, 2/1, train_loss: 0.1055, step time: 1.9602
# epoch 38, average loss: 0.1654, lr: 0.000200
#
# val 38/1000, 1/2 , time 9.8896s
# val 38/1000, 2/2 , time 0.6799s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 38
# CURRENT avg dice: 0.9163
# CURRENT wm dice: 0.9246
# CURRENT gm dice: 0.9306
# CURRENT csf dice: 0.8936
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 38 is: 0:00:46
# ----------
# epoch 39/1000
# 39/1000, 1/1, train_loss: 0.1792, step time: 7.9808
# 39/1000, 2/1, train_loss: 0.1508, step time: 1.9587
# epoch 39, average loss: 0.1622, lr: 0.000200
#
# val 39/1000, 1/2 , time 9.9396s
# val 39/1000, 2/2 , time 0.6835s
#
# CURRENT epoch: 39
# CURRENT avg dice: 0.9103
# CURRENT wm dice: 0.9184
# CURRENT gm dice: 0.9231
# CURRENT csf dice: 0.8893
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 39 is: 0:00:46
# ----------
# epoch 40/1000
# 40/1000, 1/1, train_loss: 0.1181, step time: 8.1240
# 40/1000, 2/1, train_loss: 0.1372, step time: 1.9632
# epoch 40, average loss: 0.1533, lr: 0.000200
#
# val 40/1000, 1/2 , time 10.3160s
# val 40/1000, 2/2 , time 0.6796s
#
# CURRENT epoch: 40
# CURRENT avg dice: 0.9124
# CURRENT wm dice: 0.9241
# CURRENT gm dice: 0.9285
# CURRENT csf dice: 0.8845
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 40 is: 0:00:47
# ----------
# epoch 41/1000
# 41/1000, 1/1, train_loss: 0.1728, step time: 8.0323
# 41/1000, 2/1, train_loss: 0.1682, step time: 1.9634
# epoch 41, average loss: 0.1716, lr: 0.000200
#
# val 41/1000, 1/2 , time 9.8346s
# val 41/1000, 2/2 , time 0.6772s
#
# CURRENT epoch: 41
# CURRENT avg dice: 0.9011
# CURRENT wm dice: 0.9114
# CURRENT gm dice: 0.9043
# CURRENT csf dice: 0.8875
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 41 is: 0:00:46
# ----------
# epoch 42/1000
# 42/1000, 1/1, train_loss: 0.1956, step time: 8.8300
# 42/1000, 2/1, train_loss: 0.1586, step time: 1.9620
# epoch 42, average loss: 0.1761, lr: 0.000200
#
# val 42/1000, 1/2 , time 9.8399s
# val 42/1000, 2/2 , time 0.6782s
#
# CURRENT epoch: 42
# CURRENT avg dice: 0.8781
# CURRENT wm dice: 0.8770
# CURRENT gm dice: 0.9154
# CURRENT csf dice: 0.8420
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 42 is: 0:00:46
# ----------
# epoch 43/1000
# 43/1000, 1/1, train_loss: 0.1654, step time: 8.8249
# 43/1000, 2/1, train_loss: 0.1941, step time: 1.9582
# epoch 43, average loss: 0.1759, lr: 0.000199
#
# val 43/1000, 1/2 , time 9.8550s
# val 43/1000, 2/2 , time 0.6799s
#
# CURRENT epoch: 43
# CURRENT avg dice: 0.9018
# CURRENT wm dice: 0.9066
# CURRENT gm dice: 0.9193
# CURRENT csf dice: 0.8797
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 43 is: 0:00:46
# ----------
# epoch 44/1000
# 44/1000, 1/1, train_loss: 0.1564, step time: 8.8232
# 44/1000, 2/1, train_loss: 0.1513, step time: 1.9589
# epoch 44, average loss: 0.1689, lr: 0.000199
#
# val 44/1000, 1/2 , time 9.6576s
# val 44/1000, 2/2 , time 0.6773s
#
# CURRENT epoch: 44
# CURRENT avg dice: 0.9055
# CURRENT wm dice: 0.9155
# CURRENT gm dice: 0.9232
# CURRENT csf dice: 0.8779
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 44 is: 0:00:46
# ----------
# epoch 45/1000
# 45/1000, 1/1, train_loss: 0.2217, step time: 8.8261
# 45/1000, 2/1, train_loss: 0.1762, step time: 1.9579
# epoch 45, average loss: 0.1757, lr: 0.000199
#
# val 45/1000, 1/2 , time 9.6591s
# val 45/1000, 2/2 , time 0.6765s
#
# CURRENT epoch: 45
# CURRENT avg dice: 0.7753
# CURRENT wm dice: 0.7936
# CURRENT gm dice: 0.7992
# CURRENT csf dice: 0.7330
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 45 is: 0:00:46
# ----------
# epoch 46/1000
# 46/1000, 1/1, train_loss: 0.1345, step time: 8.8263
# 46/1000, 2/1, train_loss: 0.1303, step time: 1.9573
# epoch 46, average loss: 0.1688, lr: 0.000199
#
# val 46/1000, 1/2 , time 9.8492s
# val 46/1000, 2/2 , time 0.6752s
#
# CURRENT epoch: 46
# CURRENT avg dice: 0.8995
# CURRENT wm dice: 0.9201
# CURRENT gm dice: 0.9250
# CURRENT csf dice: 0.8534
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 46 is: 0:00:46
# ----------
# epoch 47/1000
# 47/1000, 1/1, train_loss: 0.1777, step time: 8.8280
# 47/1000, 2/1, train_loss: 0.1797, step time: 1.9594
# epoch 47, average loss: 0.1718, lr: 0.000199
#
# val 47/1000, 1/2 , time 9.8758s
# val 47/1000, 2/2 , time 0.6771s
#
# CURRENT epoch: 47
# CURRENT avg dice: 0.8977
# CURRENT wm dice: 0.9132
# CURRENT gm dice: 0.9043
# CURRENT csf dice: 0.8756
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 47 is: 0:00:45
# ----------
# epoch 48/1000
# 48/1000, 1/1, train_loss: 0.1662, step time: 8.8286
# 48/1000, 2/1, train_loss: 0.1451, step time: 1.9523
# epoch 48, average loss: 0.1601, lr: 0.000199
#
# val 48/1000, 1/2 , time 9.7016s
# val 48/1000, 2/2 , time 0.6769s
#
# CURRENT epoch: 48
# CURRENT avg dice: 0.9105
# CURRENT wm dice: 0.9224
# CURRENT gm dice: 0.9300
# CURRENT csf dice: 0.8791
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 48 is: 0:00:46
# ----------
# epoch 49/1000
# 49/1000, 1/1, train_loss: 0.1764, step time: 8.8374
# 49/1000, 2/1, train_loss: 0.1178, step time: 1.9583
# epoch 49, average loss: 0.1718, lr: 0.000199
#
# val 49/1000, 1/2 , time 9.8234s
# val 49/1000, 2/2 , time 0.6792s
#
# CURRENT epoch: 49
# CURRENT avg dice: 0.8760
# CURRENT wm dice: 0.9051
# CURRENT gm dice: 0.9121
# CURRENT csf dice: 0.8107
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 49 is: 0:00:46
# ----------
# epoch 50/1000
# 50/1000, 1/1, train_loss: 0.1728, step time: 8.8268
# 50/1000, 2/1, train_loss: 0.2136, step time: 1.9586
# epoch 50, average loss: 0.1830, lr: 0.000199
#
# val 50/1000, 1/2 , time 9.8660s
# val 50/1000, 2/2 , time 0.6756s
#
# CURRENT epoch: 50
# CURRENT avg dice: 0.8943
# CURRENT wm dice: 0.9162
# CURRENT gm dice: 0.9048
# CURRENT csf dice: 0.8619
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 50 is: 0:00:46
# ----------
# epoch 51/1000
# 51/1000, 1/1, train_loss: 0.1716, step time: 8.8260
# 51/1000, 2/1, train_loss: 0.1289, step time: 1.9593
# epoch 51, average loss: 0.1681, lr: 0.000199
#
# val 51/1000, 1/2 , time 9.6422s
# val 51/1000, 2/2 , time 0.6781s
#
# CURRENT epoch: 51
# CURRENT avg dice: 0.8997
# CURRENT wm dice: 0.9146
# CURRENT gm dice: 0.9132
# CURRENT csf dice: 0.8713
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 51 is: 0:00:46
# ----------
# epoch 52/1000
# 52/1000, 1/1, train_loss: 0.1632, step time: 8.8220
# 52/1000, 2/1, train_loss: 0.1713, step time: 1.9602
# epoch 52, average loss: 0.1576, lr: 0.000199
#
# val 52/1000, 1/2 , time 9.6805s
# val 52/1000, 2/2 , time 0.6768s
#
# CURRENT epoch: 52
# CURRENT avg dice: 0.8905
# CURRENT wm dice: 0.8761
# CURRENT gm dice: 0.9162
# CURRENT csf dice: 0.8793
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 52 is: 0:00:46
# ----------
# epoch 53/1000
# 53/1000, 1/1, train_loss: 0.1106, step time: 8.8416
# 53/1000, 2/1, train_loss: 0.1219, step time: 1.9568
# epoch 53, average loss: 0.1527, lr: 0.000199
#
# val 53/1000, 1/2 , time 9.6863s
# val 53/1000, 2/2 , time 0.6766s
#
# CURRENT epoch: 53
# CURRENT avg dice: 0.9005
# CURRENT wm dice: 0.8996
# CURRENT gm dice: 0.9100
# CURRENT csf dice: 0.8919
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 53 is: 0:00:45
# ----------
# epoch 54/1000
# 54/1000, 1/1, train_loss: 0.1304, step time: 8.0292
# 54/1000, 2/1, train_loss: 0.1579, step time: 1.9354
# epoch 54, average loss: 0.1625, lr: 0.000199
#
# val 54/1000, 1/2 , time 9.7632s
# val 54/1000, 2/2 , time 0.6803s
#
# CURRENT epoch: 54
# CURRENT avg dice: 0.9133
# CURRENT wm dice: 0.9239
# CURRENT gm dice: 0.9246
# CURRENT csf dice: 0.8914
#
# BEST avg dice: 0.9163 at epoch: 38
#
# time consuming of epoch 54 is: 0:00:46
# ----------
# epoch 55/1000
# 55/1000, 1/1, train_loss: 0.1618, step time: 8.0166
# 55/1000, 2/1, train_loss: 0.1197, step time: 1.9554
# epoch 55, average loss: 0.1469, lr: 0.000199
#
# val 55/1000, 1/2 , time 9.7760s
# val 55/1000, 2/2 , time 0.6784s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 55
# CURRENT avg dice: 0.9182
# CURRENT wm dice: 0.9284
# CURRENT gm dice: 0.9357
# CURRENT csf dice: 0.8905
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 55 is: 0:00:46
# ----------
# epoch 56/1000
# 56/1000, 1/1, train_loss: 0.1456, step time: 8.0126
# 56/1000, 2/1, train_loss: 0.1390, step time: 1.9590
# epoch 56, average loss: 0.1470, lr: 0.000199
#
# val 56/1000, 1/2 , time 9.9392s
# val 56/1000, 2/2 , time 0.6781s
#
# CURRENT epoch: 56
# CURRENT avg dice: 0.9056
# CURRENT wm dice: 0.9245
# CURRENT gm dice: 0.9255
# CURRENT csf dice: 0.8668
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 56 is: 0:00:46
# ----------
# epoch 57/1000
# 57/1000, 1/1, train_loss: 0.1496, step time: 8.1045
# 57/1000, 2/1, train_loss: 0.1562, step time: 1.9551
# epoch 57, average loss: 0.1488, lr: 0.000199
#
# val 57/1000, 1/2 , time 10.0987s
# val 57/1000, 2/2 , time 0.6850s
#
# CURRENT epoch: 57
# CURRENT avg dice: 0.9131
# CURRENT wm dice: 0.9303
# CURRENT gm dice: 0.9247
# CURRENT csf dice: 0.8844
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 57 is: 0:00:47
# ----------
# epoch 58/1000
# 58/1000, 1/1, train_loss: 0.1282, step time: 7.9715
# 58/1000, 2/1, train_loss: 0.1313, step time: 1.9587
# epoch 58, average loss: 0.1421, lr: 0.000199
#
# val 58/1000, 1/2 , time 11.2668s
# val 58/1000, 2/2 , time 0.6784s
#
# CURRENT epoch: 58
# CURRENT avg dice: 0.9095
# CURRENT wm dice: 0.9211
# CURRENT gm dice: 0.9238
# CURRENT csf dice: 0.8835
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 58 is: 0:00:49
# ----------
# epoch 59/1000
# 59/1000, 1/1, train_loss: 0.1884, step time: 7.9887
# 59/1000, 2/1, train_loss: 0.1279, step time: 1.9574
# epoch 59, average loss: 0.1545, lr: 0.000199
#
# val 59/1000, 1/2 , time 10.0402s
# val 59/1000, 2/2 , time 0.6818s
#
# CURRENT epoch: 59
# CURRENT avg dice: 0.9124
# CURRENT wm dice: 0.9231
# CURRENT gm dice: 0.9253
# CURRENT csf dice: 0.8887
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 59 is: 0:00:48
# ----------
# epoch 60/1000
# 60/1000, 1/1, train_loss: 0.1450, step time: 8.1066
# 60/1000, 2/1, train_loss: 0.1471, step time: 1.9610
# epoch 60, average loss: 0.1592, lr: 0.000199
#
# val 60/1000, 1/2 , time 11.0454s
# val 60/1000, 2/2 , time 0.6886s
#
# CURRENT epoch: 60
# CURRENT avg dice: 0.9020
# CURRENT wm dice: 0.9228
# CURRENT gm dice: 0.9120
# CURRENT csf dice: 0.8713
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 60 is: 0:00:50
# ----------
# epoch 61/1000
# 61/1000, 1/1, train_loss: 0.2019, step time: 7.9814
# 61/1000, 2/1, train_loss: 0.2084, step time: 1.9751
# epoch 61, average loss: 0.1624, lr: 0.000199
#
# val 61/1000, 1/2 , time 12.0938s
# val 61/1000, 2/2 , time 0.6858s
#
# CURRENT epoch: 61
# CURRENT avg dice: 0.9052
# CURRENT wm dice: 0.9087
# CURRENT gm dice: 0.9264
# CURRENT csf dice: 0.8804
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 61 is: 0:00:54
# ----------
# epoch 62/1000
# 62/1000, 1/1, train_loss: 0.1846, step time: 8.0441
# 62/1000, 2/1, train_loss: 0.1734, step time: 1.9597
# epoch 62, average loss: 0.1558, lr: 0.000199
#
# val 62/1000, 1/2 , time 9.8677s
# val 62/1000, 2/2 , time 0.6875s
#
# CURRENT epoch: 62
# CURRENT avg dice: 0.8938
# CURRENT wm dice: 0.8978
# CURRENT gm dice: 0.9054
# CURRENT csf dice: 0.8781
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 62 is: 0:00:52
# ----------
# epoch 63/1000
# 63/1000, 1/1, train_loss: 0.1345, step time: 8.1352
# 63/1000, 2/1, train_loss: 0.1652, step time: 1.9773
# epoch 63, average loss: 0.1528, lr: 0.000199
#
# val 63/1000, 1/2 , time 10.6638s
# val 63/1000, 2/2 , time 0.6948s
#
# CURRENT epoch: 63
# CURRENT avg dice: 0.9070
# CURRENT wm dice: 0.9136
# CURRENT gm dice: 0.9296
# CURRENT csf dice: 0.8778
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 63 is: 0:00:49
# ----------
# epoch 64/1000
# 64/1000, 1/1, train_loss: 0.1401, step time: 8.0565
# 64/1000, 2/1, train_loss: 0.1477, step time: 1.9702
# epoch 64, average loss: 0.1454, lr: 0.000199
#
# val 64/1000, 1/2 , time 10.4171s
# val 64/1000, 2/2 , time 0.6824s
#
# CURRENT epoch: 64
# CURRENT avg dice: 0.9125
# CURRENT wm dice: 0.9196
# CURRENT gm dice: 0.9332
# CURRENT csf dice: 0.8846
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 64 is: 0:00:49
# ----------
# epoch 65/1000
# 65/1000, 1/1, train_loss: 0.1474, step time: 8.1509
# 65/1000, 2/1, train_loss: 0.1342, step time: 1.9691
# epoch 65, average loss: 0.1488, lr: 0.000199
#
# val 65/1000, 1/2 , time 10.1562s
# val 65/1000, 2/2 , time 0.6837s
#
# CURRENT epoch: 65
# CURRENT avg dice: 0.9167
# CURRENT wm dice: 0.9296
# CURRENT gm dice: 0.9275
# CURRENT csf dice: 0.8930
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 65 is: 0:00:49
# ----------
# epoch 66/1000
# 66/1000, 1/1, train_loss: 0.1305, step time: 8.0887
# 66/1000, 2/1, train_loss: 0.1732, step time: 1.9657
# epoch 66, average loss: 0.1439, lr: 0.000198
#
# val 66/1000, 1/2 , time 10.0536s
# val 66/1000, 2/2 , time 0.6861s
#
# CURRENT epoch: 66
# CURRENT avg dice: 0.9046
# CURRENT wm dice: 0.9107
# CURRENT gm dice: 0.9293
# CURRENT csf dice: 0.8738
#
# BEST avg dice: 0.9182 at epoch: 55
#
# time consuming of epoch 66 is: 0:00:48
# ----------
# epoch 67/1000
# 67/1000, 1/1, train_loss: 0.1673, step time: 8.1168
# 67/1000, 2/1, train_loss: 0.1161, step time: 1.9628
# epoch 67, average loss: 0.1362, lr: 0.000198
#
# val 67/1000, 1/2 , time 9.7125s
# val 67/1000, 2/2 , time 0.6803s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 67
# CURRENT avg dice: 0.9190
# CURRENT wm dice: 0.9290
# CURRENT gm dice: 0.9342
# CURRENT csf dice: 0.8939
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 67 is: 0:00:48
# ----------
# epoch 68/1000
# 68/1000, 1/1, train_loss: 0.1456, step time: 7.9357
# 68/1000, 2/1, train_loss: 0.1786, step time: 1.9604
# epoch 68, average loss: 0.1622, lr: 0.000198
#
# val 68/1000, 1/2 , time 10.6491s
# val 68/1000, 2/2 , time 0.6827s
#
# CURRENT epoch: 68
# CURRENT avg dice: 0.9030
# CURRENT wm dice: 0.9012
# CURRENT gm dice: 0.9166
# CURRENT csf dice: 0.8911
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 68 is: 0:00:48
# ----------
# epoch 69/1000
# 69/1000, 1/1, train_loss: 0.1413, step time: 8.0527
# 69/1000, 2/1, train_loss: 0.1583, step time: 1.9604
# epoch 69, average loss: 0.1364, lr: 0.000198
#
# val 69/1000, 1/2 , time 10.2528s
# val 69/1000, 2/2 , time 0.6806s
#
# CURRENT epoch: 69
# CURRENT avg dice: 0.9026
# CURRENT wm dice: 0.9155
# CURRENT gm dice: 0.9160
# CURRENT csf dice: 0.8764
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 69 is: 0:00:50
# ----------
# epoch 70/1000
# 70/1000, 1/1, train_loss: 0.1322, step time: 8.1113
# 70/1000, 2/1, train_loss: 0.1416, step time: 1.9595
# epoch 70, average loss: 0.1373, lr: 0.000198
#
# val 70/1000, 1/2 , time 9.7107s
# val 70/1000, 2/2 , time 0.6793s
#
# CURRENT epoch: 70
# CURRENT avg dice: 0.9175
# CURRENT wm dice: 0.9273
# CURRENT gm dice: 0.9360
# CURRENT csf dice: 0.8892
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 70 is: 0:00:46
# ----------
# epoch 71/1000
# 71/1000, 1/1, train_loss: 0.1237, step time: 8.0272
# 71/1000, 2/1, train_loss: 0.1630, step time: 1.9585
# epoch 71, average loss: 0.1440, lr: 0.000198
#
# val 71/1000, 1/2 , time 10.2871s
# val 71/1000, 2/2 , time 0.6796s
#
# CURRENT epoch: 71
# CURRENT avg dice: 0.9126
# CURRENT wm dice: 0.9268
# CURRENT gm dice: 0.9295
# CURRENT csf dice: 0.8815
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 71 is: 0:00:48
# ----------
# epoch 72/1000
# 72/1000, 1/1, train_loss: 0.1409, step time: 8.0874
# 72/1000, 2/1, train_loss: 0.1456, step time: 1.9693
# epoch 72, average loss: 0.1383, lr: 0.000198
#
# val 72/1000, 1/2 , time 10.7114s
# val 72/1000, 2/2 , time 0.6802s
#
# CURRENT epoch: 72
# CURRENT avg dice: 0.9162
# CURRENT wm dice: 0.9202
# CURRENT gm dice: 0.9280
# CURRENT csf dice: 0.9005
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 72 is: 0:00:49
# ----------
# epoch 73/1000
# 73/1000, 1/1, train_loss: 0.1370, step time: 7.9706
# 73/1000, 2/1, train_loss: 0.1410, step time: 1.9769
# epoch 73, average loss: 0.1396, lr: 0.000198
#
# val 73/1000, 1/2 , time 10.0292s
# val 73/1000, 2/2 , time 0.6793s
#
# CURRENT epoch: 73
# CURRENT avg dice: 0.9068
# CURRENT wm dice: 0.9278
# CURRENT gm dice: 0.9160
# CURRENT csf dice: 0.8765
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 73 is: 0:00:48
# ----------
# epoch 74/1000
# 74/1000, 1/1, train_loss: 0.1475, step time: 8.1058
# 74/1000, 2/1, train_loss: 0.1512, step time: 1.9578
# epoch 74, average loss: 0.1568, lr: 0.000198
#
# val 74/1000, 1/2 , time 10.0432s
# val 74/1000, 2/2 , time 0.6857s
#
# CURRENT epoch: 74
# CURRENT avg dice: 0.9099
# CURRENT wm dice: 0.9129
# CURRENT gm dice: 0.9242
# CURRENT csf dice: 0.8926
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 74 is: 0:00:47
# ----------
# epoch 75/1000
# 75/1000, 1/1, train_loss: 0.1421, step time: 7.9741
# 75/1000, 2/1, train_loss: 0.1499, step time: 1.9622
# epoch 75, average loss: 0.1417, lr: 0.000198
#
# val 75/1000, 1/2 , time 9.7557s
# val 75/1000, 2/2 , time 0.6793s
#
# CURRENT epoch: 75
# CURRENT avg dice: 0.9167
# CURRENT wm dice: 0.9291
# CURRENT gm dice: 0.9298
# CURRENT csf dice: 0.8913
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 75 is: 0:00:47
# ----------
# epoch 76/1000
# 76/1000, 1/1, train_loss: 0.1471, step time: 8.0570
# 76/1000, 2/1, train_loss: 0.1174, step time: 1.9515
# epoch 76, average loss: 0.1407, lr: 0.000198
#
# val 76/1000, 1/2 , time 10.0989s
# val 76/1000, 2/2 , time 0.6909s
#
# CURRENT epoch: 76
# CURRENT avg dice: 0.9091
# CURRENT wm dice: 0.9109
# CURRENT gm dice: 0.9261
# CURRENT csf dice: 0.8903
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 76 is: 0:00:49
# ----------
# epoch 77/1000
# 77/1000, 1/1, train_loss: 0.1514, step time: 8.1317
# 77/1000, 2/1, train_loss: 0.1324, step time: 1.9602
# epoch 77, average loss: 0.1348, lr: 0.000198
#
# val 77/1000, 1/2 , time 9.9566s
# val 77/1000, 2/2 , time 0.6831s
#
# CURRENT epoch: 77
# CURRENT avg dice: 0.8973
# CURRENT wm dice: 0.8895
# CURRENT gm dice: 0.9164
# CURRENT csf dice: 0.8861
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 77 is: 0:00:46
# ----------
# epoch 78/1000
# 78/1000, 1/1, train_loss: 0.1716, step time: 8.0338
# 78/1000, 2/1, train_loss: 0.1210, step time: 1.9640
# epoch 78, average loss: 0.1337, lr: 0.000198
#
# val 78/1000, 1/2 , time 10.2854s
# val 78/1000, 2/2 , time 0.6794s
#
# CURRENT epoch: 78
# CURRENT avg dice: 0.9180
# CURRENT wm dice: 0.9273
# CURRENT gm dice: 0.9345
# CURRENT csf dice: 0.8921
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 78 is: 0:00:49
# ----------
# epoch 79/1000
# 79/1000, 1/1, train_loss: 0.1727, step time: 8.0505
# 79/1000, 2/1, train_loss: 0.1505, step time: 1.9642
# epoch 79, average loss: 0.1370, lr: 0.000198
#
# val 79/1000, 1/2 , time 10.9131s
# val 79/1000, 2/2 , time 0.6867s
#
# CURRENT epoch: 79
# CURRENT avg dice: 0.9124
# CURRENT wm dice: 0.9151
# CURRENT gm dice: 0.9317
# CURRENT csf dice: 0.8904
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 79 is: 0:00:49
# ----------
# epoch 80/1000
# 80/1000, 1/1, train_loss: 0.1595, step time: 8.0671
# 80/1000, 2/1, train_loss: 0.1747, step time: 1.9688
# epoch 80, average loss: 0.1513, lr: 0.000198
#
# val 80/1000, 1/2 , time 10.4315s
# val 80/1000, 2/2 , time 0.6788s
#
# CURRENT epoch: 80
# CURRENT avg dice: 0.9066
# CURRENT wm dice: 0.9234
# CURRENT gm dice: 0.9190
# CURRENT csf dice: 0.8773
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 80 is: 0:00:48
# ----------
# epoch 81/1000
# 81/1000, 1/1, train_loss: 0.1487, step time: 8.0347
# 81/1000, 2/1, train_loss: 0.1262, step time: 1.9640
# epoch 81, average loss: 0.1399, lr: 0.000198
#
# val 81/1000, 1/2 , time 10.4431s
# val 81/1000, 2/2 , time 0.6884s
#
# CURRENT epoch: 81
# CURRENT avg dice: 0.9059
# CURRENT wm dice: 0.9170
# CURRENT gm dice: 0.9298
# CURRENT csf dice: 0.8710
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 81 is: 0:00:48
# ----------
# epoch 82/1000
# 82/1000, 1/1, train_loss: 0.1255, step time: 8.0422
# 82/1000, 2/1, train_loss: 0.1042, step time: 1.9752
# epoch 82, average loss: 0.1393, lr: 0.000197
#
# val 82/1000, 1/2 , time 10.3944s
# val 82/1000, 2/2 , time 0.6866s
#
# CURRENT epoch: 82
# CURRENT avg dice: 0.9052
# CURRENT wm dice: 0.9238
# CURRENT gm dice: 0.9072
# CURRENT csf dice: 0.8848
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 82 is: 0:00:49
# ----------
# epoch 83/1000
# 83/1000, 1/1, train_loss: 0.1198, step time: 8.0670
# 83/1000, 2/1, train_loss: 0.1528, step time: 1.9611
# epoch 83, average loss: 0.1369, lr: 0.000197
#
# val 83/1000, 1/2 , time 10.0536s
# val 83/1000, 2/2 , time 0.6985s
#
# CURRENT epoch: 83
# CURRENT avg dice: 0.9147
# CURRENT wm dice: 0.9193
# CURRENT gm dice: 0.9341
# CURRENT csf dice: 0.8907
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 83 is: 0:00:48
# ----------
# epoch 84/1000
# 84/1000, 1/1, train_loss: 0.1569, step time: 7.9961
# 84/1000, 2/1, train_loss: 0.1726, step time: 1.9597
# epoch 84, average loss: 0.1461, lr: 0.000197
#
# val 84/1000, 1/2 , time 10.9490s
# val 84/1000, 2/2 , time 0.6874s
#
# CURRENT epoch: 84
# CURRENT avg dice: 0.9151
# CURRENT wm dice: 0.9208
# CURRENT gm dice: 0.9302
# CURRENT csf dice: 0.8944
#
# BEST avg dice: 0.9190 at epoch: 67
#
# time consuming of epoch 84 is: 0:00:50
# ----------
# epoch 85/1000
# 85/1000, 1/1, train_loss: 0.1424, step time: 7.9715
# 85/1000, 2/1, train_loss: 0.1590, step time: 1.9586
# epoch 85, average loss: 0.1404, lr: 0.000197
#
# val 85/1000, 1/2 , time 10.3494s
# val 85/1000, 2/2 , time 0.6965s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 85
# CURRENT avg dice: 0.9202
# CURRENT wm dice: 0.9272
# CURRENT gm dice: 0.9333
# CURRENT csf dice: 0.9001
#
# BEST avg dice: 0.9202 at epoch: 85
#
# time consuming of epoch 85 is: 0:00:50
# ----------
# epoch 86/1000
# 86/1000, 1/1, train_loss: 0.1260, step time: 8.0746
# 86/1000, 2/1, train_loss: 0.1126, step time: 1.9571
# epoch 86, average loss: 0.1298, lr: 0.000197
#
# val 86/1000, 1/2 , time 10.4777s
# val 86/1000, 2/2 , time 0.6813s
#
# CURRENT epoch: 86
# CURRENT avg dice: 0.9121
# CURRENT wm dice: 0.9203
# CURRENT gm dice: 0.9284
# CURRENT csf dice: 0.8876
#
# BEST avg dice: 0.9202 at epoch: 85
#
# time consuming of epoch 86 is: 0:00:48
# ----------
# epoch 87/1000
# 87/1000, 1/1, train_loss: 0.1210, step time: 8.0490
# 87/1000, 2/1, train_loss: 0.1365, step time: 1.9649
# epoch 87, average loss: 0.1422, lr: 0.000197
#
# val 87/1000, 1/2 , time 10.2004s
# val 87/1000, 2/2 , time 0.6881s
#
# CURRENT epoch: 87
# CURRENT avg dice: 0.9077
# CURRENT wm dice: 0.9062
# CURRENT gm dice: 0.9293
# CURRENT csf dice: 0.8877
#
# BEST avg dice: 0.9202 at epoch: 85
#
# time consuming of epoch 87 is: 0:00:51
# ----------
# epoch 88/1000
# 88/1000, 1/1, train_loss: 0.1444, step time: 8.1353
# 88/1000, 2/1, train_loss: 0.1486, step time: 1.9573
# epoch 88, average loss: 0.1431, lr: 0.000197
#
# val 88/1000, 1/2 , time 10.5116s
# val 88/1000, 2/2 , time 0.6951s
#
# CURRENT epoch: 88
# CURRENT avg dice: 0.9026
# CURRENT wm dice: 0.9040
# CURRENT gm dice: 0.9211
# CURRENT csf dice: 0.8828
#
# BEST avg dice: 0.9202 at epoch: 85
#
# time consuming of epoch 88 is: 0:00:51
# ----------
# epoch 89/1000
# 89/1000, 1/1, train_loss: 0.1527, step time: 8.1273
# 89/1000, 2/1, train_loss: 0.1687, step time: 1.9627
# epoch 89, average loss: 0.1409, lr: 0.000197
#
# val 89/1000, 1/2 , time 10.9558s
# val 89/1000, 2/2 , time 0.6803s
#
# CURRENT epoch: 89
# CURRENT avg dice: 0.9077
# CURRENT wm dice: 0.9214
# CURRENT gm dice: 0.9158
# CURRENT csf dice: 0.8860
#
# BEST avg dice: 0.9202 at epoch: 85
#
# time consuming of epoch 89 is: 0:00:49
# ----------
# epoch 90/1000
# 90/1000, 1/1, train_loss: 0.1429, step time: 8.0103
# 90/1000, 2/1, train_loss: 0.1439, step time: 1.9586
# epoch 90, average loss: 0.1407, lr: 0.000197
#
# val 90/1000, 1/2 , time 10.1816s
# val 90/1000, 2/2 , time 0.6832s
#
# CURRENT epoch: 90
# CURRENT avg dice: 0.9150
# CURRENT wm dice: 0.9140
# CURRENT gm dice: 0.9325
# CURRENT csf dice: 0.8986
#
# BEST avg dice: 0.9202 at epoch: 85
#
# time consuming of epoch 90 is: 0:00:49
# ----------
# epoch 91/1000
# 91/1000, 1/1, train_loss: 0.1543, step time: 8.0492
# 91/1000, 2/1, train_loss: 0.1367, step time: 1.9629
# epoch 91, average loss: 0.1375, lr: 0.000197
#
# val 91/1000, 1/2 , time 10.0352s
# val 91/1000, 2/2 , time 0.6786s
#
# CURRENT epoch: 91
# CURRENT avg dice: 0.9131
# CURRENT wm dice: 0.9190
# CURRENT gm dice: 0.9232
# CURRENT csf dice: 0.8973
#
# BEST avg dice: 0.9202 at epoch: 85
#
# time consuming of epoch 91 is: 0:00:48
# ----------
# epoch 92/1000
# 92/1000, 1/1, train_loss: 0.1503, step time: 8.0471
# 92/1000, 2/1, train_loss: 0.1610, step time: 1.9570
# epoch 92, average loss: 0.1331, lr: 0.000197
#
# val 92/1000, 1/2 , time 10.3477s
# val 92/1000, 2/2 , time 0.6859s
#
# CURRENT epoch: 92
# CURRENT avg dice: 0.9182
# CURRENT wm dice: 0.9242
# CURRENT gm dice: 0.9370
# CURRENT csf dice: 0.8932
#
# BEST avg dice: 0.9202 at epoch: 85
#
# time consuming of epoch 92 is: 0:00:49
# ----------
# epoch 93/1000
# 93/1000, 1/1, train_loss: 0.1679, step time: 8.0343
# 93/1000, 2/1, train_loss: 0.1253, step time: 1.9597
# epoch 93, average loss: 0.1325, lr: 0.000197
#
# val 93/1000, 1/2 , time 11.2187s
# val 93/1000, 2/2 , time 0.6860s
#
# => SAVED NEW BEST MODEL!
#
# CURRENT epoch: 93
# CURRENT avg dice: 0.9212
# CURRENT wm dice: 0.9292
# CURRENT gm dice: 0.9341
# CURRENT csf dice: 0.9004
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 93 is: 0:00:50
# ----------
# epoch 94/1000
# 94/1000, 1/1, train_loss: 0.1309, step time: 8.0201
# 94/1000, 2/1, train_loss: 0.1428, step time: 1.9605
# epoch 94, average loss: 0.1446, lr: 0.000197
#
# val 94/1000, 1/2 , time 10.5563s
# val 94/1000, 2/2 , time 0.6802s
#
# CURRENT epoch: 94
# CURRENT avg dice: 0.9129
# CURRENT wm dice: 0.9235
# CURRENT gm dice: 0.9311
# CURRENT csf dice: 0.8842
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 94 is: 0:00:49
# ----------
# epoch 95/1000
# 95/1000, 1/1, train_loss: 0.1648, step time: 7.9824
# 95/1000, 2/1, train_loss: 0.1550, step time: 1.9611
# epoch 95, average loss: 0.1390, lr: 0.000196
#
# val 95/1000, 1/2 , time 9.5966s
# val 95/1000, 2/2 , time 0.6795s
#
# CURRENT epoch: 95
# CURRENT avg dice: 0.9150
# CURRENT wm dice: 0.9264
# CURRENT gm dice: 0.9277
# CURRENT csf dice: 0.8908
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 95 is: 0:00:46
# ----------
# epoch 96/1000
# 96/1000, 1/1, train_loss: 0.1082, step time: 8.0685
# 96/1000, 2/1, train_loss: 0.1256, step time: 1.9580
# epoch 96, average loss: 0.1322, lr: 0.000196
#
# val 96/1000, 1/2 , time 9.7789s
# val 96/1000, 2/2 , time 0.6775s
#
# CURRENT epoch: 96
# CURRENT avg dice: 0.9176
# CURRENT wm dice: 0.9211
# CURRENT gm dice: 0.9313
# CURRENT csf dice: 0.9005
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 96 is: 0:00:45
# ----------
# epoch 97/1000
# 97/1000, 1/1, train_loss: 0.1257, step time: 8.0303
# 97/1000, 2/1, train_loss: 0.1512, step time: 1.9595
# epoch 97, average loss: 0.1414, lr: 0.000196
#
# val 97/1000, 1/2 , time 9.6548s
# val 97/1000, 2/2 , time 0.6785s
#
# CURRENT epoch: 97
# CURRENT avg dice: 0.9201
# CURRENT wm dice: 0.9296
# CURRENT gm dice: 0.9375
# CURRENT csf dice: 0.8932
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 97 is: 0:00:45
# ----------
# epoch 98/1000
# 98/1000, 1/1, train_loss: 0.2387, step time: 7.9464
# 98/1000, 2/1, train_loss: 0.3119, step time: 1.9603
# epoch 98, average loss: 0.3016, lr: 0.000196
#
# val 98/1000, 1/2 , time 10.1092s
# val 98/1000, 2/2 , time 0.6812s
#
# CURRENT epoch: 98
# CURRENT avg dice: 0.5451
# CURRENT wm dice: 0.8010
# CURRENT gm dice: 0.7070
# CURRENT csf dice: 0.1275
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 98 is: 0:00:46
# ----------
# epoch 99/1000
# 99/1000, 1/1, train_loss: 0.4825, step time: 8.1268
# 99/1000, 2/1, train_loss: 2.0496, step time: 1.9451
# epoch 99, average loss: 1.5577, lr: 0.000196
#
# val 99/1000, 1/2 , time 9.9435s
# val 99/1000, 2/2 , time 0.6928s
#
# CURRENT epoch: 99
# CURRENT avg dice: 0.1547
# CURRENT wm dice: 0.2717
# CURRENT gm dice: 0.1765
# CURRENT csf dice: 0.0160
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 99 is: 0:00:47
# ----------
# epoch 100/1000
# 100/1000, 1/1, train_loss: 26.6229, step time: 8.0525
# 100/1000, 2/1, train_loss: 4.4364, step time: 1.9613
# epoch 100, average loss: 16.3311, lr: 0.000196
#
# val 100/1000, 1/2 , time 10.5711s
# val 100/1000, 2/2 , time 0.6817s
#
# CURRENT epoch: 100
# CURRENT avg dice: 0.3604
# CURRENT wm dice: 0.5556
# CURRENT gm dice: 0.5257
# CURRENT csf dice: 0.0000
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 100 is: 0:00:47
# ----------
# epoch 101/1000
# 101/1000, 1/1, train_loss: 8.4713, step time: 7.9263
# 101/1000, 2/1, train_loss: 6.3349, step time: 1.9583
# epoch 101, average loss: 13.9301, lr: 0.000196
#
# val 101/1000, 1/2 , time 10.4713s
# val 101/1000, 2/2 , time 0.6826s
#
# CURRENT epoch: 101
# CURRENT avg dice: 0.2300
# CURRENT wm dice: 0.4429
# CURRENT gm dice: 0.2446
# CURRENT csf dice: 0.0027
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 101 is: 0:00:48
# ----------
# epoch 102/1000
# 102/1000, 1/1, train_loss: 2.2620, step time: 8.0219
# 102/1000, 2/1, train_loss: 1.6987, step time: 1.9579
# epoch 102, average loss: 2.6057, lr: 0.000196
#
# val 102/1000, 1/2 , time 10.6400s
# val 102/1000, 2/2 , time 0.6858s
#
# CURRENT epoch: 102
# CURRENT avg dice: 0.4480
# CURRENT wm dice: 0.6666
# CURRENT gm dice: 0.6773
# CURRENT csf dice: 0.0000
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 102 is: 0:00:48
# ----------
# epoch 103/1000
# 103/1000, 1/1, train_loss: 0.8232, step time: 7.9897
# 103/1000, 2/1, train_loss: 0.8224, step time: 1.9531
# epoch 103, average loss: 1.0177, lr: 0.000196
#
# val 103/1000, 1/2 , time 10.9109s
# val 103/1000, 2/2 , time 0.6823s
#
# CURRENT epoch: 103
# CURRENT avg dice: 0.5294
# CURRENT wm dice: 0.8362
# CURRENT gm dice: 0.7504
# CURRENT csf dice: 0.0016
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 103 is: 0:00:48
# ----------
# epoch 104/1000
# 104/1000, 1/1, train_loss: 0.6103, step time: 7.8914
# 104/1000, 2/1, train_loss: 0.7186, step time: 1.9475
# epoch 104, average loss: 0.7754, lr: 0.000196
#
# val 104/1000, 1/2 , time 10.5869s
# val 104/1000, 2/2 , time 0.6860s
#
# CURRENT epoch: 104
# CURRENT avg dice: 0.5711
# CURRENT wm dice: 0.8556
# CURRENT gm dice: 0.8137
# CURRENT csf dice: 0.0441
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 104 is: 0:00:49
# ----------
# epoch 105/1000
# 105/1000, 1/1, train_loss: 0.5584, step time: 7.9488
# 105/1000, 2/1, train_loss: 0.6977, step time: 1.9514
# epoch 105, average loss: 0.6511, lr: 0.000196
#
# val 105/1000, 1/2 , time 10.7208s
# val 105/1000, 2/2 , time 0.6873s
#
# CURRENT epoch: 105
# CURRENT avg dice: 0.6179
# CURRENT wm dice: 0.8638
# CURRENT gm dice: 0.8361
# CURRENT csf dice: 0.1539
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 105 is: 0:00:49
# ----------
# epoch 106/1000
# 106/1000, 1/1, train_loss: 0.5140, step time: 8.0777
# 106/1000, 2/1, train_loss: 0.5576, step time: 1.9411
# epoch 106, average loss: 0.5449, lr: 0.000195
#
# val 106/1000, 1/2 , time 10.3525s
# val 106/1000, 2/2 , time 0.6872s
#
# CURRENT epoch: 106
# CURRENT avg dice: 0.7169
# CURRENT wm dice: 0.8724
# CURRENT gm dice: 0.8570
# CURRENT csf dice: 0.4213
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 106 is: 0:00:48
# ----------
# epoch 107/1000
# 107/1000, 1/1, train_loss: 0.3922, step time: 7.8949
# 107/1000, 2/1, train_loss: 0.4527, step time: 1.9462
# epoch 107, average loss: 0.4693, lr: 0.000195
#
# val 107/1000, 1/2 , time 9.9350s
# val 107/1000, 2/2 , time 0.6805s
#
# CURRENT epoch: 107
# CURRENT avg dice: 0.7539
# CURRENT wm dice: 0.8792
# CURRENT gm dice: 0.8622
# CURRENT csf dice: 0.5204
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 107 is: 0:00:47
# ----------
# epoch 108/1000
# 108/1000, 1/1, train_loss: 0.4602, step time: 7.9689
# 108/1000, 2/1, train_loss: 0.3925, step time: 1.9490
# epoch 108, average loss: 0.4038, lr: 0.000195
#
# val 108/1000, 1/2 , time 10.6483s
# val 108/1000, 2/2 , time 0.6950s
#
# CURRENT epoch: 108
# CURRENT avg dice: 0.8027
# CURRENT wm dice: 0.8799
# CURRENT gm dice: 0.8671
# CURRENT csf dice: 0.6611
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 108 is: 0:00:48
# ----------
# epoch 109/1000
# 109/1000, 1/1, train_loss: 0.3479, step time: 7.9237
# 109/1000, 2/1, train_loss: 0.3887, step time: 1.9443
# epoch 109, average loss: 0.3903, lr: 0.000195
#
# val 109/1000, 1/2 , time 10.4951s
# val 109/1000, 2/2 , time 0.6786s
#
# CURRENT epoch: 109
# CURRENT avg dice: 0.8188
# CURRENT wm dice: 0.8837
# CURRENT gm dice: 0.8741
# CURRENT csf dice: 0.6985
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 109 is: 0:00:50
# ----------
# epoch 110/1000
# 110/1000, 1/1, train_loss: 0.3551, step time: 8.0904
# 110/1000, 2/1, train_loss: 0.3028, step time: 1.9610
# epoch 110, average loss: 0.3256, lr: 0.000195
#
# val 110/1000, 1/2 , time 11.6492s
# val 110/1000, 2/2 , time 0.6848s
#
# CURRENT epoch: 110
# CURRENT avg dice: 0.8282
# CURRENT wm dice: 0.8823
# CURRENT gm dice: 0.8744
# CURRENT csf dice: 0.7280
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 110 is: 0:00:58
# ----------
# epoch 111/1000
# 111/1000, 1/1, train_loss: 0.3539, step time: 7.9702
# 111/1000, 2/1, train_loss: 0.4472, step time: 1.9483
# epoch 111, average loss: 0.3503, lr: 0.000195
#
# val 111/1000, 1/2 , time 10.4712s
# val 111/1000, 2/2 , time 0.6816s
#
# CURRENT epoch: 111
# CURRENT avg dice: 0.8235
# CURRENT wm dice: 0.8815
# CURRENT gm dice: 0.8780
# CURRENT csf dice: 0.7109
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 111 is: 0:00:49
# ----------
# epoch 112/1000
# 112/1000, 1/1, train_loss: 0.2684, step time: 8.0568
# 112/1000, 2/1, train_loss: 0.4099, step time: 1.9417
# epoch 112, average loss: 0.3372, lr: 0.000195
#
# val 112/1000, 1/2 , time 10.2162s
# val 112/1000, 2/2 , time 0.6802s
#
# CURRENT epoch: 112
# CURRENT avg dice: 0.8206
# CURRENT wm dice: 0.8820
# CURRENT gm dice: 0.8729
# CURRENT csf dice: 0.7067
#
# BEST avg dice: 0.9212 at epoch: 93
#
# time consuming of epoch 112 is: 0:00:48
# ----------
# epoch 113/1000
# 113/1000, 1/1, train_loss: 0.2701, step time: 7.9399
# 113/1000, 2/1, train_loss: 0.2998, step time: 1.9411
# epoch 113, average loss: 0.2971, lr: 0.000195
#
# val 113/1000, 1/2 , time 11.0438s
# val 113/1000, 2/2 , time 0.6814s
#
# CURRENT epoch: 113
# CURRENT avg dice: 0.8378
# CURRENT wm dice: 0.8816
# CURRENT gm dice: 0.8768
# CURRENT csf dice: 0.7551
#
# BEST avg dice: 0.9212 at epoch: 93
#
# => EARLY STOPPING

# %%
total_time_formatted = str(datetime.timedelta(seconds=int(total_time)))

print(f"training completed, best_avg_dice: {best_avg_dice:.4f} at epoch: {best_dice_epoch}, total time: {total_time_formatted}.")
# Out:
# training completed, best_avg_dice: 0.9212 at epoch: 93, total time: 1:30:29.

# %% [markdown]
# ## Evaluate

# %%
other_dir = "D:\\Files\\Projects\\MAIA\\UdG\MISA\\Project\\experiments\\exp01-SegResNet-20231230_18_50_32"
model.load_state_dict(torch.load(os.path.join(other_dir, "best_metric_model.pth")))
model.to(device)
model.eval()

y_true = []
y_pred = []

infer_transform = transforms.AsDiscrete(argmax=True)

val_start = time.time()
with torch.no_grad():
    for idx, val_data in enumerate(val_loader):
        
        val_inputs = (
            val_data["image"].as_tensor()
            if isinstance(val_data["image"], data.MetaTensor)
            else val_data["image"]
        )
        val_labels = (
            val_data["label"].as_tensor()
            if isinstance(val_data["label"], data.MetaTensor)
            else val_data["label"]
        )
        
        val_inputs = val_inputs.to(device)
        val_labels = val_labels.to(device)

        val_outputs = inference(val_inputs)
        
        val_outputs_list = data.decollate_batch(val_outputs)
        val_labels_list = data.decollate_batch(val_labels)
        
        val_outputs_convert = [infer_transform(val_output) for val_output in val_outputs_list]
        val_labels_convert = val_labels_list
                    
        print(
            f"infer {idx + 1}/{len(val_loader)}",
            f", time {(time.time() - val_start):.4f}s",
        )
        val_start = time.time()
                
        for i in range(len(val_outputs_convert)):
            y_true.append(val_labels_convert[i].cpu().numpy())
            y_pred.append(val_outputs_convert[i].cpu().numpy())
# Out:
# infer 1/2 , time 12.2276s
# infer 2/2 , time 1.3248s

# %%
# plot first label and pred
print(f"y_true[0] type: {type(y_true[0])}")
print(f"y_true[0] shape: {y_true[0].shape}")
print(f"y_true[0] dtype: {y_true[0].dtype}")
print(f"y_pred[0] type: {type(y_pred[0])}")
print(f"y_pred[0] shape: {y_pred[0].shape}")
print(f"y_pred[0] dtype: {y_pred[0].dtype}")
plt.figure("label", (6, 4))
plt.subplot(1, 2, 1)
plt.title("label")
plt.imshow(y_true[0][0, :, :, IMG_SIZE[2]//2])
plt.subplot(1, 2, 2)
plt.title("pred")
plt.imshow(y_pred[0][0, :, :, IMG_SIZE[2]//2])
plt.show()
# Out:
# y_true[0] type: <class 'numpy.ndarray'>
# y_true[0] shape: (1, 256, 128, 256)
# y_true[0] dtype: float32
# y_pred[0] type: <class 'numpy.ndarray'>
# y_pred[0] shape: (1, 256, 128, 256)
# y_pred[0] dtype: float32

# %%
def calculate_dice_score(labels_seg, labels_gt, print_score=True):
    dice_score = {}
    
    # please check what are the actual label values for the dataset you are working with

    label_seg_csf = labels_seg == 1
    label_seg_gm = labels_seg == 2
    label_seg_wm = labels_seg == 3

    label_gt_csf = labels_gt == 1
    label_gt_gm = labels_gt == 2
    label_gt_wm = labels_gt == 3

    dice_score['csf'] = np.sum(label_gt_csf[label_seg_csf]) * 2.0 / (np.sum(label_gt_csf) + np.sum(label_seg_csf))
    dice_score['gm'] = np.sum(label_gt_gm[label_seg_gm]) * 2.0 / (np.sum(label_gt_gm) + np.sum(label_seg_gm))
    dice_score['wm'] = np.sum(label_gt_wm[label_seg_wm]) * 2.0 / (np.sum(label_gt_wm) + np.sum(label_seg_wm))

    if print_score:
        print('Dice scores:')
        for key, value in dice_score.items():
            print(f'{key}: {value:.4f}')
            
        print(f'Average: {np.mean(list(dice_score.values())):.4f}')

    return dice_score

# %%
import SimpleITK as sitk

def calculate_hausdorff_distance(labels_pred, labels_gt, print_score=True):
    """
    Calculate the Hausdorff distance for each label in the predicted and ground truth segmentation.

    Parameters
    ----------
    labels_pred : numpy array
        Predicted segmentation labels.
    labels_gt : numpy array
        Ground truth segmentation labels.
    print_score : bool, optional
        Whether to print the Hausdorff distance for each label, by default True.

    Returns
    -------
    hd_score : dict
        Dictionary containing the Hausdorff distance for each label.
    """
    # Convert numpy arrays to SimpleITK images
    pred_image = sitk.GetImageFromArray(labels_pred)
    gt_image = sitk.GetImageFromArray(labels_gt)

    # Create the Hausdorff distance filter
    hd_filter = sitk.HausdorffDistanceImageFilter()

    # Calculate the Hausdorff distance for each label
    hd_scores = {}
    for label, label_name in zip([1, 2, 3], ['csf', 'gm', 'wm']):
        pred_label = sitk.BinaryThreshold(pred_image, label, label)
        gt_label = sitk.BinaryThreshold(gt_image, label, label)

        hd_filter.Execute(pred_label, gt_label)
        hd_scores[label_name] = hd_filter.GetHausdorffDistance()
    
    if print_score:
        print('Hausdorff distance:')
        for key, value in hd_scores.items():
            print(f'{key}: {value:.4f}')
        
        print(f'Average: {np.mean(list(hd_scores.values())):.4f}')

    return hd_scores

# %%
def calculate_avd(pred_labels, gt_labels, print_scores=True):
    """
    Calculate the average volumetric difference (AVD) per label between predicted and ground truth labels.

    Parameters
    ----------
    pred_labels : numpy.ndarray
        Predicted segmentation labels.
    gt_labels : numpy.ndarray
        Ground truth segmentation labels.
    print_scores : bool, optional
        Whether to print the AVD scores per label, by default True.

    Returns
    -------
    avd_scores : dict
        Dictionary containing the average volumetric difference (AVD) score per label.
    """
    avd_scores = {}
    
    for label, label_name in zip([1, 2, 3], ['csf', 'gm', 'wm']):
        pred_label = pred_labels == label
        gt_label = gt_labels == label

        avd_scores[label_name] = np.abs(np.sum(pred_label) - np.sum(gt_label)) / np.sum(gt_label)

    if print_scores:
        print("Average Volumetric Difference (AVD) per label:")
        for label, score in avd_scores.items():
            print(f"Label {label}: {score:.4f}")
            
        print(f"Average: {np.mean(list(avd_scores.values())):.4f}")

    return avd_scores

# %%
dice_scores = []
hd_scores = []
avd_scores = []

for i in range(len(y_true)):
    # squeeze the channel dimension
    y_true[i] = np.squeeze(y_true[i])
    y_pred[i] = np.squeeze(y_pred[i])
    
    # plot the data
    plt.figure("check", (6, 6))
    plt.subplot(1, 2, 1)
    plt.title("prediction")
    plt.imshow(y_pred[i][:, :, 150])
    plt.subplot(1, 2, 2)
    plt.title("ground truth")
    plt.imshow(y_true[i][:, :, 150])
    plt.show()
    
    dice_scores.append(calculate_dice_score(y_pred[i], y_true[i]))
    print()
    hd_scores.append(calculate_hausdorff_distance(y_pred[i], y_true[i]))
    print()
    avd_scores.append(calculate_avd(y_pred[i], y_true[i]))
    
print()
print("#" * 50)
print("AVERAGE SCORES FOR ALL CASES")
print("#" * 50)

# calculate the average for csf, gm, and wm for dice scores
print("\nAverage dice scores for all cases:")
average_dice_score = {}
for key in dice_scores[0].keys():
    average_dice_score[key] = np.mean([dice_score[key] for dice_score in dice_scores])
for key, value in average_dice_score.items():
    print(f"{key}: {value:.4f}")
print(f"Total average: {np.mean(list(average_dice_score.values())):.4f}")

# calculate the average for csf, gm, and wm for Hausdorff scores
print("\nAverage Hausdorff scores for all cases:")
average_hd_score = {}
for key in hd_scores[0].keys():
    average_hd_score[key] = np.mean([hd_score[key] for hd_score in hd_scores])
for key, value in average_hd_score.items():
    print(f"{key}: {value:.4f}")
print(f"Total average: {np.mean(list(average_hd_score.values())):.4f}")

# calculate the average for csf, gm, and wm for AVD scores
print("\nAverage AVD scores for all cases:")
average_avd_score = {}
for key in avd_scores[0].keys():
    average_avd_score[key] = np.mean([avd_score[key] for avd_score in avd_scores])
for key, value in average_avd_score.items():
    print(f"{key}: {value:.4f}")
print(f"Total average: {np.mean(list(average_avd_score.values())):.4f}")
# Out:
# Dice scores:
# csf: 0.8782
# gm: 0.9330
# wm: 0.9473
# Average: 0.9195
#
# Hausdorff distance:
# csf: 10.0995
# gm: 7.1414
# wm: 7.5498
# Average: 8.2636
#
# Average Volumetric Difference (AVD) per label:
# Label csf: 0.0329
# Label gm: 0.0012
# Label wm: 0.0462
# Average: 0.0268
# Dice scores:
# csf: 0.9005
# gm: 0.9176
# wm: 0.9297
# Average: 0.9159
#
# Hausdorff distance:
# csf: 16.2788
# gm: 9.2736
# wm: 8.0623
# Average: 11.2049
#
# Average Volumetric Difference (AVD) per label:
# Label csf: 0.1264
# Label gm: 0.0218
# Label wm: 0.0802
# Average: 0.0761
# Dice scores:
# csf: 0.8764
# gm: 0.9323
# wm: 0.9075
# Average: 0.9054
#
# Hausdorff distance:
# csf: 14.8997
# gm: 11.0000
# wm: 8.2462
# Average: 11.3820
#
# Average Volumetric Difference (AVD) per label:
# Label csf: 0.0757
# Label gm: 0.0554
# Label wm: 0.1004
# Average: 0.0771
# Dice scores:
# csf: 0.9192
# gm: 0.9472
# wm: 0.9429
# Average: 0.9364
#
# Hausdorff distance:
# csf: 35.9166
# gm: 8.6023
# wm: 6.5574
# Average: 17.0254
#
# Average Volumetric Difference (AVD) per label:
# Label csf: 0.0080
# Label gm: 0.0169
# Label wm: 0.0040
# Average: 0.0096
# Dice scores:
# csf: 0.9281
# gm: 0.9403
# wm: 0.9185
# Average: 0.9290
#
# Hausdorff distance:
# csf: 14.2478
# gm: 8.6603
# wm: 9.4868
# Average: 10.7983
#
# Average Volumetric Difference (AVD) per label:
# Label csf: 0.0032
# Label gm: 0.0239
# Label wm: 0.0481
# Average: 0.0250
#
# ##################################################
# AVERAGE SCORES FOR ALL CASES
# ##################################################
#
# Average dice scores for all cases:
# csf: 0.9005
# gm: 0.9341
# wm: 0.9292
# Total average: 0.9212
#
# Average Hausdorff scores for all cases:
# csf: 18.2885
# gm: 8.9355
# wm: 7.9805
# Total average: 11.7348
#
# Average AVD scores for all cases:
# csf: 0.0492
# gm: 0.0238
# wm: 0.0558
# Total average: 0.0429

# %%
# create a dataframe with all the scores, both per case and average
import pandas as pd

val_cases_orig = [11, 12, 13, 14, 17]

df_dice_orig = pd.DataFrame(dice_scores)
df_dice = df_dice_orig.copy()
df_dice['average'] = df_dice_orig.mean(axis=1)
df_dice['std'] = df_dice_orig.std(axis=1)

df_hausdorff_orig = pd.DataFrame(hd_scores)
df_hausdorff = df_hausdorff_orig.copy()
df_hausdorff['average'] = df_hausdorff_orig.mean(axis=1)
df_hausdorff['std'] = df_hausdorff_orig.std(axis=1)

df_avd_orig = pd.DataFrame(avd_scores)
df_avd = df_avd_orig.copy()
df_avd['average'] = df_avd_orig.mean(axis=1)
df_avd['std'] = df_avd_orig.std(axis=1)

df_scores = pd.concat([df_dice, df_hausdorff, df_avd], axis=1)
df_scores.index = val_cases_orig

# rename the columns
df_scores.columns = [
    'dice_csf', 'dice_gm', 'dice_wm', 'dice_average', 'dice_std',
    'hd', 'hd_gm', 'hd_wm', 'hd_average', 'hd_std',
    'avd_csf', 'avd_gm', 'avd_wm', 'avd_average', 'avd_std'
]

# export to excel
df_scores.to_excel('results/exp01_scores.xlsx')

# %%
import matplotlib.pyplot as plt

n_slice = 150

# Create subplots with 3 rows and the number of columns based on the number of images
fig, axes = plt.subplots(2, len(y_true), figsize=(12, 8))

# Add vertical text to indicate original, prediction, and ground truth
axes[0, 0].text(-20, 128, "Prediction", rotation="vertical", va="center", ha="center", fontsize=12)
axes[1, 0].text(-20, 128, "Ground Truth", rotation="vertical", va="center", ha="center", fontsize=12)

# Plot predictions
for i in range(len(y_pred)):
    axes[0, i].imshow(y_pred[i][:, :, n_slice])
    axes[0, i].set_title(f"Case {val_cases_orig[i]}")
    axes[0, i].axis("off")

# Plot ground truth
for i in range(len(y_true)):
    axes[1, i].imshow(y_true[i][:, :, n_slice])
    axes[1, i].set_title(f"Case {val_cases_orig[i]}")
    axes[1, i].axis("off")

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.1, hspace=0.1)

# Show the plot
plt.show()

# %%
n_slice = 150

# Create subplots with 3 rows and the number of columns based on the number of images
fig, axes = plt.subplots(2, len(y_true), figsize=(12, 8))

# Add vertical text to indicate original, prediction, and ground truth
axes[0, 0].text(-20, 128, "Image", rotation="vertical", va="center", ha="center", fontsize=12)
axes[1, 0].text(-20, 128, "Ground Truth", rotation="vertical", va="center", ha="center", fontsize=12)

# Plot predictions
for i in range(len(y_pred)):
    val_img_to_plot = val_ds[i]["image"].cpu().numpy()[0, :, :, n_slice]
    
    axes[0, i].imshow(val_img_to_plot, cmap="gray")
    axes[0, i].set_title(f"Case {val_cases_orig[i]}")
    axes[0, i].axis("off")

# Plot ground truth
for i in range(len(y_true)):
    axes[1, i].imshow(y_true[i][:, :, n_slice])
    axes[1, i].set_title(f"Case {val_cases_orig[i]}")
    axes[1, i].axis("off")

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.1, hspace=0.1)

# Show the plot
plt.show()
